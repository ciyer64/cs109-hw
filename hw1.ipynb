# %% [markdown]
# # HW1: Who is the best singer ever? Rihanna or Mariah?

# %% [markdown]
# <img width=600 height=400 src="http://static.idolator.com/uploads/2015/02/rihanna-mariah.jpg"/>
#
# Billboard Magazine puts out a top 100 list of "singles" every week. Information from this list, as well as that from music sales, radio, and other sources is used to determine a top-100 "singles" of the year list. A **single** is typically one song, but sometimes can be two songs which are on one "single" record.
#
# In this homework you will scrape both Wikipedia and Billboard Magazine to try to understand how the public's taste in music has evolved. You will do this by learning about the best singers and groups from each year (distinguishing between the two groups) as determined by the Billboard top 100 charts. You will have to scrape the web pages, clean the data, and visualize the performance of the artists and their songs. Finally, you'll find some "features" which might predict performance on the year end charts from the weekly ones.
#
# (Image credit: http://www.idolator.com/7579645/rihanna-mariah-carey-vision-of-love-made-her-want-to-do-music)

# %% [markdown]
# ## **This homework is due Thursday 24th September, at 11:59PM.**

# %% [markdown]
# We will use the **LAST COMMIT** BEFORE 11:59PM on Thursday Sep 24th 2015, on the **hw1** branch, of your repository `cs109-students/githubusername-2015hw` as your submission.

# %% [markdown]
# The homework will help develop your skills in:
#
# - web page scraping
# - data cleaning and manipulation
# - pandas
# - simple exploratory data visualization
# - thinking about data and what features might be used to make predictions
#
# You should have worked through Lab 1 (the pandas and python parts) and Lab 2.
#
# The table of contents below shows youthe structure of the homework. The headings with numbers like 1.2 and 3.2 are the ones that need to be answered. At lot of code is provided for you in this homework. DO NOT simply run it. Understand it. I promise that if you dont, you will have trouble in the parts that you have to code.
#
# Finally, start soon. This is not a very long homework, but we are at the point in the semester that logistical issues like git flow and python running might hold you up.

# %% [markdown]
# #Table of Contents
# * [HW1: Who is the best singer ever? Rihanna or Mariah?](#HW1:-Who-is-the-best-singer-ever?-Rihanna-or-Mariah?)
# 	* [**This homework is due Thursday 24th September, at 11:59PM.**](#**This-homework-is-due-Thursday-24th-September,-at-11:59PM.**)
# 	* [Q1. Scraping Wikipedia for Billboard Top 100.](#Q1.-Scraping-Wikipedia-for-Billboard-Top-100.)
# 		* [Scraping Wikipedia for Billboard singles](#Scraping-Wikipedia-for-Billboard-singles)
# 			* [Parsing the Billboard Wikipedia page for 1970](#Parsing-the-Billboard-Wikipedia-page-for-1970)
# 			* [1.1 Generalize the previous: Scrape wikipedia from 1992 to 2014](#1.1-Generalize-the-previous:-Scrape-wikipedia-from-1992-to-2014)
# 			* [1.2 Clean data and save a json file of information from the scraped files](#1.2-Clean-data-and-save-a-json-file-of-information-from-the-scraped-files)
# 		* [Construct a year-song-singer dataframe from the yearly information](#Construct-a-year-song-singer-dataframe-from-the-yearly-information)
# 			* [Construct a panel and flatten it](#Construct-a-panel-and-flatten-it)
# 			* [Cleaning data: the correct datatypes](#Cleaning-data:-the-correct-datatypes)
# 	* [Q2. Scraping and Constructing: Information about Artists, Bands and Genres from Wikipedia](#Q2.-Scraping-and-Constructing:-Information-about-Artists,-Bands-and-Genres-from-Wikipedia)
# 		* [Scrape information about artists from wikipedia](#Scrape-information-about-artists-from-wikipedia)
# 			* [Pulling and saving the data](#Pulling-and-saving-the-data)
# 			* [2.1 Extract information about singers and bands](#2.1-Extract-information-about-singers-and-bands)
# 			* [Merging this information in](#Merging-this-information-in)
# 			* [2.2 Split out the genres](#2.2-Split-out-the-genres)
# 	* [Q3. Exploratory Data Analysis (EDA)](#Q3.-Exploratory-Data-Analysis-%28EDA%29)
# 		* [What has been the trajectory of various genres in the popular zeitgeist?](#What-has-been-the-trajectory-of-various-genres-in-the-popular-zeitgeist?)
# 			* [3.1 Plot a horizontal bar chart of the top 30 genres](#3.1-Plot-a-horizontal-bar-chart-of-the-top-30-genres)
# 			* [3.2 Make a small multiples plot of the 24 most popular genres](#3.2-Make-a-small-multiples-plot-of-the-24-most-popular-genres)
# 		* [Who are the highest quality singers?](#Who-are-the-highest-quality-singers?)
# 			* [3.3 What if we used a different metric?](#3.3-What-if-we-used-a-different-metric?)
# 			* [The age at which singers achieve their top ranking.](#The-age-at-which-singers-achieve-their-top-ranking.)
# 			* [3.4 At what year since inception do bands reach their top rankings?](#3.4-At-what-year-since-inception-do-bands-reach-their-top-rankings?)
# 	* [Q4: Billboard Magazine: year end results from weekly results](#Q4:-Billboard-Magazine:-year-end-results-from-weekly-results)
# 		* [Get the end year results, and results from all saturdays of the year.](#Get-the-end-year-results,-and-results-from-all-saturdays-of-the-year.)
# 			* [Get the data](#Get-the-data)
# 			* [4.1 Parse the HTML and save the song information](#4.1-Parse-the-HTML-and-save-the-song-information)
# 		* [Get winning songs, and see how they do in all these weeks](#Get-winning-songs,-and-see-how-they-do-in-all-these-weeks)
# 			* [4.2 Plot the mean rank(y axis) against the final, year-end rank(x-axis)](#4.2-Plot-the-mean-rank%28y-axis%29-against-the-final,-year-end-rank%28x-axis%29)
# 		* [Add losers in and see what features may be used to distinguish winners from losers](#Add-losers-in-and-see-what-features-may-be-used-to-distinguish-winners-from-losers)
# 			* [4.3 Make a scatterplot matrix of these features, color coded by winners/losers](#4.3-Make-a-scatterplot-matrix-of-these-features,-color-coded-by-winners/losers)

# %% [markdown]
# ---

# %% [markdown]
# Python depends on packages for most of its functionality; these can be either built-in (such as sys), or third-party (like all the packages below). Either way you need to import the packages you need before using them.

# %%
# The %... is an iPython thing, and is not part of the Python language.
# In this case we're just telling the plotting library to draw things on
# the notebook, instead of on a separate window.
# %matplotlib inline
# See all the "as ..." contructs? They're just aliasing the package names.
# That way we can call methods like plt.plot() instead of matplotlib.pyplot.plot().
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# We use [Seaborn](http://stanford.edu/~mwaskom/software/seaborn/) to give us a nicer default color palette, with our plots being of large (`poster`) size and with a white-grid background. (see the code above).

# %% [markdown]
# ## Q1. Scraping Wikipedia for Billboard Top 100.

# %% [markdown]
# In this question you will scrape wikipedia for Billboard's top 100. You may use any python scraping software you like. We especially recommend Beautiful Soup and PyQuery.

# %% [markdown]
# ### Scraping Wikipedia for Billboard singles

# %% [markdown]
# We'll be using one of two libraries to transform HTML content into Python data structures. One is [BeautifulSoup](http://www.crummy.com/software/BeautifulSoup/) and the other is [PyQuery](https://pythonhosted.org/pyquery/).
#
# You can choose which one you want to use.
#
# PyQuery is recommended for people who have used [jQuery](https://jquery.com/) before, or who feel more comfortable using CSS selectors. BeautifulSoup on the other hand might be a better  fit for people who are familiar with Python. Either package will make the job of parsing HTML documents easier.

# %%
from pyquery import PyQuery as pq
from bs4 import BeautifulSoup
# The "requests" library makes working with HTTP requests easier
# than the built-in urllib libraries.
import requests

# %% [markdown]
# #### Parsing the Billboard Wikipedia page for 1970

# %% [markdown]
# We'll use python's `requests` module to obtain the web page at http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970. From this web page we'll extract the top 100 singles and their rankings. We'll then create a list of [dictionaries](https://docs.python.org/2/tutorial/datastructures.html#dictionaries), 100 of them to be precise, with entries like `{'url': '/wiki/Sugarloaf_(band)', 'ranking': 30, 'band_singer': 'Sugarloaf', 'title': 'Green-Eyed Lady'}`. If you look at that web page, you will see that there is a link for every song, from which you can get the `url` of the singer or band. We will use these links later to scrape information about the singer or band. From the listing we can also get the band or singer name `band_singer`, and `title` of the song.
#
# We start by making a [GET](http://www.w3schools.com/tags/ref_httpmethods.asp) request to pull in the Billboard page from Wikipedia. This is the equivalent of using your browser to visit the page.
#
# In fact, you should visit the link above right now and [look at the source code of the page in the developer tools](http://wickedlysmart.com/hfhtml5/devtools.html), so you can follow what we'll be doing in the next few lines (Hint: in Chrome you can just hit F12 to get the developer tools).

# %%
# here we access the webpage and download the content using requests
t1970=requests.get("http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970")

# %% [markdown]
# Next we will need to look for the HTML _tr_ (table row) element, but only the one that has a CSS class of _wikitable_. If you look at the page source, you'll see a construct like __class=wikitable__ on the table in question. But you will also notice that none of the _tr_ elements actually have the __class__ attribute set directly on them.
#
# A full depth treatment of [CSS](http://www.w3schools.com/css/) [selectors](http://www.w3schools.com/cssref/css_selectors.asp) are beyond the scope of this course, but you just need to learn enough to enable you to scrape. For now you can think of it this way: children (embedded) elements inherit style properties from their parents, unless they have the property explicitly reset on their tag attributes.
#
# Here is a screenshot of that page with the developer tools opened in Safari. I clicked Inspect and then the word "Title" to make this appear.
#
# ![1970 songs](wikipage.png)

# %% [markdown]
# **_Read this if you would like to use pyquery_** . Otherwise, skip down a bit to the part where we use beautifulSoup.
#
# When you request a web page, the HTTP server on the other side of the connection sends a lot of meta-information along with the page content your browser renders. Because we are only interested in the page content (i.e. the HTML elements), we request the _text_ property of the request result (the lack of parenthesis after _text_ is a hint that we're asking the object for a property, and not calling a method).

# %%
d_=pq(t1970.text)

# %% [markdown]
# That text is then parsed by PyQuery (which was aliased as pq) and the result is bound to the _d\__ variable. The naming choice here is to mimic jQuery's \$ variable. Python is very flexible with identifier names for variables, functions, etc. They can't start with numbers, and underscores at the start and end of the name are somewhat special, but otherwise you have a lot of freedom naming them. Python is case sensitive, so my_var is different from My_var, which is different from MY_VAR, etc. Also, don't use Python [keywords](https://docs.python.org/2/reference/lexical_analysis.html#keywords) or built-in function names for your variables and functions. Weird things can happen if you do...
#
# The construct below generates a list like structure of _tr_ elements. The __[1:]__ part at the end means that we are only interested elements from the second position to the end of the list (in Python, indexes start at zero); that is because the first _tr_ element actually holds the table header.

# %%
d_rows=pq(d_('.wikitable tr')[1:])

# %% [markdown]
# Next we'll be calling the _text_ method of the PyQuery object, which will return the text between the opening and closing _tr_ tags. Note that as with the _requests_ response, this object contains a lot more information about the elements than just the text, which is why we need to explicitly tell it we only want the latter.
#
# You might have noticed that when we wanted the text content of the HTTP request we accessed its _text_ property, but this time we called the _text_ method (the parenthesis after the property name show that we're making a method call). Libraries are created by different people and are not always consistent. Please refer to the package documentation when in doubt.
#
# We will now parse the elements inside the _tr_ tags to get the data we need. I'll switch to inline comments to make it easier to follow the logic.

# %%
# Start by creating an empty list.
songs=[]

# Iterate over the elements of d_rows. In this case "r" will
# receive each value from "d_rows" in turn.
for r in d_rows:
    # Extract the "td" element from the current value of r.
    d_td=pq(r)('td')
    # Get the text from the first (index zero) "td" element, and convert
    # it to an integer. If you have the page open, this is the value on
    # the first column of the row (i.e. the song position on the chart).
    ranking = int(pq(d_td[0]).text())
    # The second column holds an "a" element, so we need to extract that
    # before getting the text data. This is the song title.
    title=pq(d_td[1])('a').text()
    # We then get the singer name, which is the text of the third column.
    band_singer=pq(d_td[2])('a').text()
    # Along with the singer name, we also want to get the URL to her Wikipedia page,
    # which is held on the "href" attribute of the a element.
    # Notice that we are still looking the same element we used to get the name (index 2).
    band_singer_url=pq(d_td[2])('a').attr.href
    # Next we'll place all this information on a dictionary (also called
    # a map, an associative array, a hash, etc.). We will use dictionaries
    # a lot, so it's worth to do some quick research on this versatil Python
    # structure.
    songdict=dict(ranking=ranking, title=title, band_singer=band_singer, url=band_singer_url)
    # Here we're just printing the dicitonary that was created during this iteration.
    # Lastly, we add the dictionary with the row information to the list we
    # created in the begining of the cell.
    # Lists will also be used extensively during the course, 
    # so you might as well do some reserach on it too.
    songs.append(songdict)

# %% [markdown]
# You should now have a nice list of dictionaries with all the information you needed from the Wikipedia page.

# %%
# By the way, indexes are open on the upper bound.
# So songs[2:4] will give us the third and fourth elements, but not the fifth.
songs[2:4]
# Out:
# [{'band_singer': 'The Guess Who',
#   'ranking': 3,
#   'title': 'American Woman',
#   'url': '/wiki/The_Guess_Who'},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': 4,
#   'title': "Raindrops Keep Fallin' on My Head",
#   'url': '/wiki/B.J._Thomas'}]

# %% [markdown]
# ---
#
# **_Read this if you would like to use Beautiful Soup_**
#
# We will now show how to accomplish the same thing with BeautifulSoup. We will also take the opportunity to showcase a programming style called Functional Programming. This style is very useful to data manipulation, and it involves encapsulating your code into small, well contained functions which call each other. My way of working is to usually write my code first, after which I **refactor** pieces of code into functions which I can then reuse in the future. Functional programming is very useful and great to know, but can get some time to get used to. It is absolutely not a requirement for this class, but we would like you to know about it, and even if you don't write in this style yourself, to be able to understand your team mates code.
#
# If you find the following constructs confusing, feel free to ignore them for now. It should be noted that Python is not a functional language, but it does have some attributes that allow semi-functional programs to be created.
#
# If you want to read more about the `BeautifulSoup` functions we use, please have a look at the [documentation](http://www.crummy.com/software/BeautifulSoup/bs4/doc/).
#
# The construct in the line `rows = soup.find...` below generates a list like structure of _tr_ elements. The __[1:]__ part at the end means that we are only interested elements from the second position to the end of the list (in Python, indexes start at zero); that is because the first _tr_ element actually holds the table header.

# %%
# We'll just reuse the request object that was previously created to create a BeautifulSoup element.
# The latter will be the equivalent of the "d_" object we created before.
soup = BeautifulSoup(t1970.text, "html.parser")

# In this line we are looking for a single "table" element with a class of wikitable;
# and then looking for all the "tr" elements on that table (notice the find vs find_all calls).
# Even though the syntax is very different from PyQuery, the end result is similar.
rows = soup.find("table", attrs={"class": "wikitable"}).find_all("tr")[1:]

# We then define an anonymous (lambda) function whose job it is to act on
#each column's element in each row in the table. Lambda functions are very
# handy for functional programming, and the one below should be easy to follow.
# The function processes each field of the parameter r accordingly. It starts by
# transforming the first column into an integer; it then proceeds to getting the text
# from the second and third elements, and finally it gets the HTTP link of the third
# element, and returns all that in a list (notice the surrounding brackets).
# The function is then bound to the cleaner variable so it can be referenced later.
cleaner = lambda r: [int(r[0].get_text()), r[1].get_text(), r[2].get_text(), r[2].find("a").get("href")]

#lambda functions are also excellent for defining one line math functions.
#e.g. radius = lambda x,y: np.sqrt(x*x + y*y)

# Next we'll create a list of names that will be used as dictionary keys.
fields = ["ranking", "title", "band_singer", "url"]

# We now use the lambda function to process each "td" element on a given row.
# the [... for ... in ...] construct is a list comprehension. They look weird at
# first but are amazingly useful and worth spending some time to learn.
# At a high level, thing of it as a one line "for loop" that aggregates the result
# of each iteration into a list. So once this line finished running, we will have a list
# of something.
#
# The dict function is another way to create a dictionary. One neat thing about it
# is that it accepts a list of key/value pairs that will be used to create said dictionary.
#
# But where are these key/value pairs coming from in here? From the zip function!
# The zip function will take multiple iterables (things that can be treated as a sequence)
# and combine them. An example might make it clearer:
#
# zip(["a", "b", "c"], [1, 2, 3]) evaluates to [("a", 1), ("b", 2), ("c", 3)]. It's like a zipper!!!
#
# Anyway, never mind the parenthesis around the pairs; they just show that the elements
# are grouped into tuples, which you can think of as lists that are immutable (they can't grow or shrink).
#
# So to recap: the zip function creates a list of pairs; which the dict function then uses
# to create a dictionary, using the first element of the pair as the key and the second as
# the value; and finally, the list comprehension iterates over each row element, and puts
# the result of each iteration on a list, which is then bound to the songs variable.
songs = [dict(zip(fields, cleaner(row.find_all("td")))) for row in rows]

# %% [markdown]
# The cell above has a lot of comments, but only 5 lines of Python code. Functional programs have a tendency to be more concise and, once you get the gist of it, easier to understand.

# %%
songs[2:4]
# Out:
# [{'band_singer': u'The Guess Who',
#   'ranking': 3,
#   'title': u'"American Woman"',
#   'url': u'/wiki/The_Guess_Who'},
#  {'band_singer': u'B.J. Thomas',
#   'ranking': 4,
#   'title': u'"Raindrops Keep Fallin\' on My Head"',
#   'url': u'/wiki/B.J._Thomas'}]

# %% [markdown]
# In the end, we have a list with the same contents as the one created by the PyQuery version. On the next section you will have to parse the tables for multiple years. Pick one of the approaches presented above and adapt it to solve that problem. Or come up with your own solution!

# %% [markdown]
# #### 1.1 Generalize the previous: Scrape wikipedia from 1992 to 2014

# %% [markdown]
# By visiting the urls similar to the ones for 1970, we can obtain the billboard top 100 for the years 1992 to 2014. Download these using `requests` and store the text from those requests in a dictionary called `yearstext`. This dictionary ought to have as its keys the years (as integers from 1992 to 2014), and as values corresponding to these keys the text of the page being fetched.
#
# You ought to sleep a second at the very least in-between fetching each web page: you do not want Wikipedia to think you are a marauding bot attempting to mount a denial-of-service attack.

# %% [markdown]
# *Here are some notes for how you may do this*:
#
# You can start by using [`range`](https://docs.python.org/2/library/functions.html#range) to create a list of numbers from 1992 to 2014 (in its simplest form the `range` function returns a list of numbers from 0 to the argument given minus one). On a side note, if you need to generate a huge list of numbers (over thousands of numbers), use the _xrange_ function instead.
#
# You can then use [string interpolation](https://docs.python.org/2/library/stdtypes.html#string-formatting) to request the page for each year from 1992 to 2014. These pages are added to a dictionary with the year as the key and the page text as the value.
#
# The `time.sleep` function can be used to wait one second between requests, otherwise Wikipedia might get mad at us.
#
# At the end of the cell below, the dictionary `yearstext` **must** be defined.

# %%
#your code here
#list of years
yearcount = range(1992,2015)

#list of requests
#initially empty
requestlist = []
#filling the request list
for i in range(len(yearcount)):
    requestlist.append(requests.get("http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_ %d" %yearcount[i]))
    requestlist[i] = requestlist[i].text
    requestlist[i] = BeautifulSoup(requestlist[i], "html.parser")
    time.sleep(0.1)

yearstext = dict(zip(yearcount,requestlist))

# %% [markdown]
# #### 1.2 Clean data and save a json file of information from the scraped files

# %% [markdown]
# Remember the code you wrote to get data from 1970 which produces a list of dictionaries, one corresponding to each single? Write a function `parse_year(year, yeartextdict)` which takes the year, prints it out, gets the text for the year from the just created year text dictionary, and return a list of dictionaries for that year, with one dictionary for each single.
#
# The dictionaries **must** be of this form:
#
# ```
# {'band_singer': ['Brandy', 'Monica'],
#   'ranking': 2,
#   'song': ['The Boy Is Mine'],
#   'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
#   'titletext': '" The Boy Is Mine "',
#   'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
# ```

# %% [markdown]
# Notice that some singles might have multiple songs:
#
# ```
# {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']}
# ```

# %% [markdown]
# And some don't have a song URL:
#
# ```
# {'band_singer': [u'Nu Flavor'],
#   'ranking': 91,
#   'song': [u'Heaven'],
#   'songurl': [None],
#   'titletext': u'"Heaven"',
#   'url': [u'/wiki/Nu_Flavor']}
# ```

# %% [markdown]
# There are some additional issues this function must handle:
#
# 1. There can be more than one one `band_singer` as can be seen above (sometimes with a comma, sometimes with "featuring" in between). The best way to parse these is to look for the urls.
# 2. There can be 2 songs in a single, because of the way the industry works: there are 2 sided singles. See https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1997 for example. You can find other examples in 1998 and 1999.
# 3. The `titletext` is the contents of the table cell, and retains the quotes that wikipedia puts on the single.
# 4. If no song anchor is found (see the 24th song in the above url), assume there is one song in the single, set `songurl` to [`None`] and the song name to the contents of the table cell with the quotes stripped (ie `song` is a one-element list with this the `titletext` stripped of its quotes).

# %% [markdown]
# As a test, try the following:

# %%
"""
Function
--------
parse_year

Inputs
------
year: the year you want the singles for
ytextdixt: a dictionary with keys as integer years and values the downloaded web pages 
    from wikipedia for that year.
   
Returns
-------

a list of dictionaries, each of which corresponds to a single and has the
following data:

Eg:

{'band_singer': ['Brandy', 'Monica'],
  'ranking': 2,
  'song': ['The Boy Is Mine'],
  'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
  'titletext': '" The Boy Is Mine "',
  'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
  
A dictionary with the following data:
    band_singer: a list of bands/singers who made this single
    song: a list of the titles of songs on this single
    songurl: a list of the same size as song which has urls for the songs on the single 
        (see point 3 above)
    ranking: ranking of the single
    titletext: the contents of the table cell
    band_singer: a list of bands or singers on this single
    url: a list of wikipedia singer/band urls on this single: only put in the part 
        of the url from /wiki onwards
    

Notes
-----
See description and example above.
"""
#your code here
import unicodedata

def parse_year(year,yeardict):
    print year
    keys = ['band_singer','ranking','song','songurl','titletext','url']
    #ranking done, songurl done, titletext done, url done
    rows = yeardict[year].find("table", attrs={"class": "wikitable"}).find_all("tr")[1:]
    songdictlist = []
    #print rows
    for row in rows:
        info = row.find_all("td")
        #print(info[1].get_text())
        #print info
        song_info = info[0].find_all("a")
        #print song_info
        band_info = info[1].find_all("a")
        #print info[1].get_text()
        superlist = []
        
        #list of singers/bands
        singer_list = []
        for i in range(len(band_info)):
            band_name = band_info[i].get("title")
            singer_list.append(unicodedata.normalize('NFKD',band_name).encode('ascii','ignore'))
        #print "Singer(s):", singer_list
        superlist.append(singer_list)
 
        #single ranking
        ranking = row.find("th").get_text()
        #print "Ranking:", ranking
        superlist.append(int(ranking))
        
        #list of songs
        song_list = []
        for i in range(len(song_info)):
            song_name = song_info[i].get_text()
            song_list.append(unicodedata.normalize('NFKD',song_name).encode('ascii','ignore'))
        if song_list == []:
            song_name = unicodedata.normalize('NFKD',info[0].get_text()).encode('ascii','ignore')
            song_list.append(song_name[1:(len(song_name)-1)])
        #print "Song(s):", song_list
        superlist.append(song_list)
        
        #list of song URLs
        song_url_list = []
        for i in range(len(song_info)):
            song_url = song_info[i].get("href")
            song_url_list.append(str(song_url))
        if song_url_list == []:
            song_url_list.append(None)
        #print "Song URL(s):", song_url_list
        superlist.append(song_url_list)
        
        #title of song(s)
        titletext = info[0].get_text()
        #print "Title:", titletext
        superlist.append(unicodedata.normalize('NFKD',titletext).encode('ascii','ignore'))
        
        #list of band URLs
        band_url_list = []
        for i in range(len(band_info)):
            band_url = band_info[i].get("href")
            band_url_list.append(str(band_url))
        if band_url_list == []:
            band_url_list.append(None)
        #print "Band URL(s):", band_url_list
        superlist.append(band_url_list)
        #print(superlist)
        singleinfo = dict(zip(keys,superlist))
        #print(singleinfo)
        songdictlist.append(singleinfo)
    #print songdictlist
    return songdictlist

#parse_year(1997,yearstext)

# %%
parse_year(1997, yearstext)[:5]
# Out:
# 1997
# [{'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': '"Something About the Way You Look Tonight" / "Candle in the Wind 1997"',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel (singer)'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '"Foolish Games" / "You Were Meant for Me"',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Sean Combs', 'Faith Evans', '112 (band)'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': '"I\'ll Be Missing You"',
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': '"Un-Break My Heart"',
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Sean Combs', 'Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': '"Can\'t Nobody Hold Me Down"',
#   'url': ['/wiki/Sean_Combs', '/wiki/Mase']}]

# %% [markdown]
# This should give the following. Notice that the year 1997 exercises the edge cases we talked about earlier.

# %% [raw]
# [{'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': '" Something About the Way You Look Tonight " / " Candle in the Wind 1997 "',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Puff Daddy', 'Faith Evans', '112'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': '" I\'ll Be Missing You "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': '" Un-Break My Heart "',
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Puff Daddy', 'Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': '" Can\'t Nobody Hold Me Down "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Mase']}]

# %% [markdown]
# Then, let us store the information for each year in a dictionary `yearinfo` keyed by year.

# %%
yearinfo = {y:parse_year(y, yearstext) for y in yearcount}
# Out:
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014

# %% [markdown]
# We would not want to lose all this work, so let's save the last data structure we created to disk. That way if you need to re-run sections 1.3 and beyond, you don't need to redo all these requests and parsing. Notice that we save into the `tempdata` folder. If you look at the `.gitignore` for this repository, you will see that files in `tempdata` are not committed...these are large files, and when you commit and push your homework, we do not need to see them...

# %%
import json

# %%
fd = open("tempdata/yearinfo.json","w")
json.dump(yearinfo, fd)
fd.close()

# %% [markdown]
# Now let's reload our JSON file into the yearinfo variable, just to be sure everything is working.

# %%
# Another way to deal with files. Has the advantage of closing the file for you.
del yearinfo
with open("tempdata/yearinfo.json", "r") as fd:
    yearinfo = json.load(fd)

# %% [markdown]
# ### Construct a year-song-singer dataframe from the yearly information

# %% [markdown]
# Let's construct a dataframe from the `yearinfo`. Pandas DataFrames are like Excel spreadsheets or CSV files. They are great for representing data that has the same data type on each column, but different types across columns. However, if you look at the data structure we have so far, a given key can have a list of values with multiple entries. Also, our data is grouped by year. So we need a way to flatten this data into a format that will create a useful DataFrame.

# %% [markdown]
# #### Construct a panel and flatten it

# %% [markdown]
# To do this, we iterate over the years and the singles per year. For each single, we then iterate over singers and songs, in the end constructing a dataframe for each year. This dataframe has one row per single/singer/song combination. We can then store these dataframes into a dictionary, construct a Panel from it (look it up in the Pandas docs), and flatten the panel to get a hierarchically indexed dataframe.
#
# A Panel is a 3-D version of a DataFrame, or a DataFrame of DataFrames. Think of dataframes stacked on top of each other and coming out of the screen. We then flatten this Panel into a single Dataframe by using Pandas ability to have hierarchical indexing: in this case its the ranking/year combination that things get flattened under.
#
# Don't worry if you don't get the Panel to DataFrame part. We will have plenty of time to learn about Pandas and its data structures. But make sure you understand the logic of everything before the last three lines.

# %%
yeardict={}
for y in yearinfo.keys():
    yearlist=yearinfo[y]
    yearlist2=[]
    for idict in yearlist:
        singers=idict['band_singer']
        for i,s in enumerate(singers):
            songs=idict['song']
            for j,so in enumerate(songs):#now inside each singer song combination
                nd={}
                nd['band_singer']=s
                nd['url']=idict['url'][i]
                nd['song']=so
                nd['songurl']=idict['songurl'][j]
                nd['ranking']=idict['ranking']
                yearlist2.append(nd)
    yeardict[y]=pd.DataFrame(yearlist2)#one for each year
yearspanel=pd.Panel.from_dict(yeardict, orient="minor")#stack dataframes into a panel
hierframe=yearspanel.to_frame() #flattening leads to a hierarchical index

# %%
hierframe.head()
# Out:
#                  band_singer  ranking                    song                                            songurl                     url
# major minor
# 0     1992       Boyz II Men        1         End of the Road                              /wiki/End_of_the_Road       /wiki/Boyz_II_Men
#       1993   Whitney Houston        1  I Will Always Love You  /wiki/I_Will_Always_Love_You#Whitney_Houston_v...   /wiki/Whitney_Houston
#       1994       Ace of Base        1                The Sign                              /wiki/The_Sign_(song)       /wiki/Ace_of_Base
#       1995            Coolio        1      Gangsta's Paradise                  /wiki/Gangsta%27s_Paradise_(song)            /wiki/Coolio
#       1996       Los del Rio        1                Macarena                              /wiki/Macarena_(song)  /wiki/Los_del_R%C3%ADo

# %% [markdown]
# We really want a non-hierarchical dataframe. So, let's flatten the dataframe further and rename some of the items in the index to create a non-hierarchically indexed dataframe.

# %%
flatframe = hierframe.reset_index()
flatframe.head()
# Out:
#    major minor      band_singer  ranking                    song                                            songurl                     url
# 0      0  1992      Boyz II Men        1         End of the Road                              /wiki/End_of_the_Road       /wiki/Boyz_II_Men
# 1      0  1993  Whitney Houston        1  I Will Always Love You  /wiki/I_Will_Always_Love_You#Whitney_Houston_v...   /wiki/Whitney_Houston
# 2      0  1994      Ace of Base        1                The Sign                              /wiki/The_Sign_(song)       /wiki/Ace_of_Base
# 3      0  1995           Coolio        1      Gangsta's Paradise                  /wiki/Gangsta%27s_Paradise_(song)            /wiki/Coolio
# 4      0  1996      Los del Rio        1                Macarena                              /wiki/Macarena_(song)  /wiki/Los_del_R%C3%ADo

# %%
flatframe = flatframe.rename(columns={'minor':'year'})
del flatframe['major']
flatframe.head(8)
# Out:
#    year      band_singer  ranking                                      song                                            songurl                     url
# 0  1992      Boyz II Men        1                           End of the Road                              /wiki/End_of_the_Road       /wiki/Boyz_II_Men
# 1  1993  Whitney Houston        1                    I Will Always Love You  /wiki/I_Will_Always_Love_You#Whitney_Houston_v...   /wiki/Whitney_Houston
# 2  1994      Ace of Base        1                                  The Sign                              /wiki/The_Sign_(song)       /wiki/Ace_of_Base
# 3  1995           Coolio        1                        Gangsta's Paradise                  /wiki/Gangsta%27s_Paradise_(song)            /wiki/Coolio
# 4  1996      Los del Rio        1                                  Macarena                              /wiki/Macarena_(song)  /wiki/Los_del_R%C3%ADo
# 5  1997       Elton John        1  Something About the Way You Look Tonight     /wiki/Something_About_the_Way_You_Look_Tonight        /wiki/Elton_John
# 6  1998     Next (group)        1                                 Too Close                        /wiki/Too_Close_(Next_song)      /wiki/Next_(group)
# 7  1999             Cher        1                                   Believe                          /wiki/Believe_(Cher_song)              /wiki/Cher

# %% [markdown]
# #### Cleaning data: the correct datatypes

# %% [markdown]
# Now let's check if the DataFrame has the right data types.

# %%
flatframe.dtypes
# Out:
# year            object
# band_singer     object
# ranking        float64
# song            object
# songurl         object
# url             object
# dtype: object

# %% [markdown]
# Pandas treats strings as generic objects, so most fields look right. However, in **1.1** we used the _range_ function to create the years, which means our dictionary should have integer keys, which should in turn become integer values on the DataFrame. What gives (hint: everything looked right until we restored the data from the JSON file)?

# %% [markdown]
# We should fix that. We use the [astype](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html) function to transform the data on the _year_ column from string to integer.

# %%
flatframe.year = flatframe.year.astype(int)
flatframe.dtypes
# Out:
# year             int64
# band_singer     object
# ranking        float64
# song            object
# songurl         object
# url             object
# dtype: object

# %% [markdown]
# ## Q2. Scraping and Constructing: Information about Artists, Bands and Genres from Wikipedia

# %% [markdown]
# Our next job is to use those singer urls and get information about singers and/or bands. Here is an example.

# %%
for th in pq(requests.get("http://en.wikipedia.org/wiki/Jason_Derulo").text)(".infobox tr th"):
    if pq(th).text() == "Genres":
        for e in pq(th).nextAll("td li a"):
            if pq(e).attr.href.find("#cite_note") == -1:
                print pq(e).attr.href, pq(e).attr.title
# Out:
# /wiki/Contemporary_R%26B Contemporary R&B
# /wiki/Hip_hop_music Hip hop music
# /wiki/Pop_music Pop music

# %% [markdown]
# ### Scrape information about artists from wikipedia

# %% [markdown]
# We wish to fetch information about the singers or groups for all the winning songs in a list of years.
#
# Here we show a function that fetches information about a singer or group from their url on wikipedia. The function uses a `requests` call.
#
# If the request gets an HTTP code different from 200, the cells for that URL will have a value of 1; and if the request completely fails (e.g. no network connection) the cell will have a value of 2. This will allow you to analyse the failed requests.
#
# Notice that we have wrapped the call in whats called _an exception block_. We try to make the request. If it fails entirely, or returns a HTTP code thats not 200, we set the status to 2 and 1 respectively.
#
# We also create a cache object `urlcache` that will avoid redundant HTTP requests (e.g. an artist might have multiple singles on a single year, or be on the list over a span of years). Remember that this function is designed to be used in a loop over years, and then a loop over songs per year. It stands to reason that prolific singers or bands will show up again and again. Since network requests are relatively slow, if we have already getched a singer or band's wikipedia page, caching the results is a smart thing to do.
#
# For those interested in digging deeper into these types of optimization, check out _memoization_ techniques, and the _lru_cache_ function on the _functools_ package.

# %%
urlcache={}

# %%
def get_page(url):
    # Check if URL has already been visited.
    if (url not in urlcache) or (urlcache[url]==1) or (urlcache[url]==2):
        time.sleep(1)
        # try/except blocks are used whenever the code could generate an exception (e.g. division by zero).
        # In this case we don't know if the page really exists, or even if it does, if we'll be able to reach it.
        try:
            r = requests.get("http://en.wikipedia.org%s" % url)

            if r.status_code == 200:
                urlcache[url] = r.text
            else:
                urlcache[url] = 1
        except:
            urlcache[url] = 2
    return urlcache[url]

# %% [markdown]
# We sort the `flatframe` by year, ascending, first. Why? It ensures that we will hit the cache most as singers who show up repeatedly in the rankings will have their information already pulled.

# %%
flatframe=flatframe.sort('year')

# %% [markdown]
# #### Pulling and saving the data

# %% [markdown]
# **Note**: the function below takes a fair bit of time, about 25 minutes, for me.

# %%
# Here we are populating the url cache
# subsequent calls to this cell should be very fast, since Python won't
# need to fetch the page from the web server.
#NOTE this function will take quite some time to run (about 25 mins for me), since we sleep 1 second before
#making a request. If you run it again it will be almost instantaneous, save requests that might have failed
#(you will need to run it again if requests fail..see cell below for how to test this)
flatframe["url"].apply(get_page)
# Out:
# 0       <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 529     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2155    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 552     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2133    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 575     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 598     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2088    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 620     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 643     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2043    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 666     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2021    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 689     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 1998    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 712     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 1976    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 735     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 1954    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 758     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2178    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 506     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2201    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2223    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 161     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 184     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 207     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 230     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 253     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 276     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
#                               ...
# 1054    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 1776    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 1528    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 1393    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2286    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2547    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2688    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2110    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2855    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2671    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2844    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 734     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 1799    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 367     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 1257    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 1416    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 1953    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 1077    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2944    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2354    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2832    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 436     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 22      <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2263    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2132    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2200    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 1617    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 505     <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2720    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# 2582    <!DOCTYPE html>\n<html lang="en" dir="ltr" cla...
# Name: url, dtype: object

# %% [markdown]
# You may have to run this function again and again, incase there were network problems and such. Notice that because there is a "global" cache, it will take less time each time you run it. Also note that this function is designed to be run again and again: it just tries to make sure that there are no unresolved pages left. Let us make sure of this: *the sum below should be 0, and the boolean True.*

# %%
print np.sum([(urlcache[k]==1) or (urlcache[k]==2) for k in urlcache])# no one or 0's
print len(flatframe.url.unique())==len(urlcache)#we got all of the urls
# Out:
# 0
# True

# %% [markdown]
# Let's save the `urlcache` to disk and remove the old object.

# %%
with open("tempdata/artistinfo.json","w") as fd:
    json.dump(urlcache, fd)
del urlcache

# %% [markdown]
# Now let's reload the dictionary from the JSON file.

# %%
with open("tempdata/artistinfo.json") as json_file:
    urlcache = json.load(json_file)

# %% [markdown]
# #### 2.1 Extract information about singers and bands

# %% [markdown]
# From each page we collected about a singer or a band, extract the following information:
#
# 1. The genres that the band or singer works in (sidebar on right). These genres should be urls, this ensures their uniqueness. Create a list of these urls `genres`. If no genres, use `['NA']`.
#
# 2. If the page has the text "Born" in the sidebar on the right, extract the element with the class `.bday`. If no "Born", store `False`. Store either of these into the variable `born`. We want to analyze the artist's age.
#
# 3. If the text "Years active" is found, but no "born", assume a band. Store into the variable `ya` the value of the next table cell corresponding to this, or `False` if the text is not found.
#
# Put this all into a function `singer_band_info` which takes the singer/band url as argument and returns a dictionary `dict(url=url, genres=genres, born=born, ya=ya)`.
#
# The information can be found on the sidebar on each such wikipedia page, as the example here shows:
#
# ![sandg](sandg.png).
#
# Once again, we can use the developer tools to divulge the structure of the web page:
#
# ![diana](dianaross.png)

# %% [markdown]
# Please write the function `singer_band_info` according to the following specification:

# %%
"""
Function
--------
singer_band_info

Inputs
------
url: the url
page_text: the text associated with the url
   
Returns
-------
A dictionary with the following data:
    url: copy the input argument url into this value
    genres: the genres that the band or singer works in
    born: the artist's birthday
    ya: years active variable

Notes
-----
See description above. Also note that some of the genres urls might require a 
bit of care and special handling.
"""

#your code here
def singer_band_info(url, page_text):
    #print url
    
    #initialization
    hasbday = False
    genres = [] 
    genre_list1 = []
    genre_list2 = []
    genrez1 = []
    genrez2 = []
    ya = None
    singer_band_dict = {}
    keys = ['url','genres','born','ya']
    #url done, born done, genres done
    page_text = BeautifulSoup(page_text, 'html.parser')
    
    #find the table
    rows = page_text.find("table", attrs={"class":"infobox"})
    #if no table
    if rows == None:
        return singer_band_dict
    else:
        rows = rows.find_all("tr")[2:]
        
    #iterate through table
    for row in rows:
        bday_row = row.find("span",attrs={"class":"bday"})
        #print bday_row
        
        #find birthday
        if bday_row != None:
            bday = bday_row.get_text()
            bday = str(unicodedata.normalize('NFKD',bday).encode('ascii','ignore'))
            if bday[0] == '(':
                bday = bday[1:len(bday)-1]
            hasbday = True
            
        #find genre & clean
        genre = row.find("th", attrs={"scope":"row"})
        if genre != None:
            genre = genre.get_text("href")
            if genre == "Genres":
                genre_list1 = row.find_all("div",attrs={"class":"hlist"})
                if genre_list1 == []:
                    genre_list2 = row.find_all("td")
                    for genre2 in genre_list2:
                        if genre2.find("a") == None:
                            genre_2 = str(genre2.get_text())
                        else:
                            genre_2 = genre2.find("a")
                        genrez2.append(genre_2)
                else:
                    genrez1 = genre_list1[0].find_all("li")
                    
        #find years active
        yact = row.find("th",attrs={"scope":"row"})
        #print yact
        if yact != None:
            yact = str(unicodedata.normalize('NFKD',yact.get_text()).encode('ascii','ignore'))
            if yact == "Years active":
                yalist = row.find_all("td")
                #print yalist
                ya = row.find("td").get_text()
                ya = str(unicodedata.normalize('NFKD',ya).encode('ascii','ignore'))
                ya = ya.replace('\n','')
                ya = ya.replace('Late','')
                if 'present' in ya:
                    ya = ya[:ya.index('present')+7]
                if 'Music' in ya:
                    ya = ya[ya.index('Music')+7:]
                if len(ya) > 4:
                    year_started = ya[:4]
                    if ya[4] == '[':
                        year_ended = ya[7:]
                    else:
                        year_ended = ya[4:]
                    ya = year_started + '-' + year_ended
    #cleaning genres
    if genrez1 != []:
        for genre in genrez1:
            if genre.find("a") == None:
                genre_url = genre.get_text()
            else:
                genre_url = genre.find("a").get("href")
            genres.append(str(genre_url))
    elif genrez2 != []:
        #print genrez2
        for genre in genrez2:
            if type(genre) == str:
                genres.append(genre)
            else:
                genre_url = genre.get("href")
                genres.append(str(genre_url))
                
    #if nothing found
    if genres == []:
        genres.append('NA')
    if hasbday == False:
        bday = False
    if ya == None:
        ya = False
    
    #list of relevant values
    superlist = [str(url), genres, bday, ya]
    
    #print superlist
    #print "URL:", url
    #print "Birthday:", bday
    #print "Genres:", genres
    #print "Years active:", ya
    singer_band_dict = dict(zip(keys,superlist))
    #print singer_band_dict
    #print url, ya
    return singer_band_dict

#singer_band_info('/wiki/Take_That',get_page('/wiki/Take_That'))
#singer_band_info('/wiki/Snoop_Dogg',get_page('/wiki/Snoop_Dogg'))
#singer_band_info('/wiki/Cher',get_page('/wiki/Cher'))

# %% [markdown]
# #### Merging this information in

# %% [markdown]
# Let's iterate over the items in the singer-group dictionary cache `urlcache`, run the above function, and create a dataframe from there.

# %%
singer_band_info_list=[]
for k,v in urlcache.items():
    singer_band_info_list.append(singer_band_info(k, v))
# Out:
# /wiki/Daughtry_(band) 2006-present
# /wiki/Ronald_Isley 1954-present
# /wiki/Rick_Ross_(rapper) 2001-present
# /wiki/Miley_Cyrus 2006-present
# /wiki/Fantasia_Barrino 2004-present
# /wiki/Billy_Currington 1996-present
# /wiki/Gina_G 1990-1998, 2004present
# /wiki/Juicy_J 1990-present
# /wiki/En_Vogue 1989-present
# /wiki/Warren_G 1992-present
# /wiki/Joan_Osborne 1989-present
# /wiki/Tove_Lo 2006-present
# /wiki/The_Veronicas 2004-present
# /wiki/Jim_Jones_(rapper) 1997-present
# /wiki/Ne-Yo 1998-present
# /wiki/The_Cover_Girls 1986-1996, 2001present
# /wiki/Mark_Wills 1996-present
# /wiki/Britney_Spears 1992-present
# /wiki/LSG 1996-2003
# /wiki/Kanye_West 1996-present
# /wiki/Crucial_Conflict 1991-present
# /wiki/Field_Mob 1999-present
# /wiki/Adam_Lambert 2009-present
# /wiki/Eric_Ben%C3%A9t 1984-present
# /wiki/Fastball_(band) 1995-present
# /wiki/Adele 2006-present
# /wiki/Alanis_Morissette 1990-present
# /wiki/IMx 1992--present
# /wiki/Kylie_Minogue 1987-present
# /wiki/Shawn_Mullins 1990-present
# /wiki/702_(band) 1993--2006 (1993-2006)
# /wiki/Bonnie_Raitt 1971-present
# /wiki/LeAnn_Rimes 1991-present
# /wiki/Three_6_Mafia 1991-2011, 2013present
# /wiki/S_Club_7 1998-20032014present
# /wiki/Crash_Test_Dummies 1988-present
# /wiki/Mac_Miller 2007-present
# /wiki/Rich_Gang False
# /wiki/98_Degrees 1995--present
# /wiki/Finger_Eleven 1989-present
# /wiki/Dido_(singer) 1995-present
# /wiki/Donell_Jones 1993-present
# /wiki/Sol%C3%A9 1993-present
# /wiki/Bruce_Springsteen 1965-present
# /wiki/Big_Pun 1992-2000
# /wiki/Deep_Blue_Something 1992-2001, 2014Present
# /wiki/Kardinal_Offishall 1994-present
# /wiki/Tweet_(singer) 2000-present
# /wiki/Ricky_Martin 1984-present
# /wiki/The_Product_G%26B 1998-present
# /wiki/Next_(band) 1994-present
# /wiki/Better_Than_Ezra 1988-present
# /wiki/Loreena_McKennitt 1985-present
# /wiki/Foster_the_People 2009-present
# /wiki/Mr._President_(band) 1991-2008
# /wiki/Aqua_(band) 1995-20012007-present
# /wiki/CeCe_Peniston 1991-present
# /wiki/Soul_for_Real 1992-present
# /wiki/Sonique_(musician) 1985-2006, 2009present
# /wiki/D4L 2003-2006
# /wiki/Shinedown 2001-present
# /wiki/Flipmode_Squad 1996-present
# /wiki/Jimmy_Ray  199-0s  present
# /wiki/Audioslave 2001-2007
# /wiki/Montell_Jordan 1994-2010
# /wiki/T-Pain 2004-present
# /wiki/D%27Angelo 1991-present
# /wiki/Jimmy_Buffett 1969-present
# /wiki/Olivia_(singer) 2000-present
# /wiki/Jennifer_Nettles 1996-present
# /wiki/All_Saints_(group) 1993-2001, 200609, 2013present
# /wiki/Common_(rapper) 1992-present
# /wiki/Next_(group) 1994-present
# /wiki/Avant 1999-present
# /wiki/Yung_Joc 2004-present
# /wiki/AZ_(rapper) 1992-  present
# /wiki/Jesse_McCartney 1999-present
# /wiki/Robert_Miles 1984-present
# /wiki/Jon_Secada 1988-present
# /wiki/Faith_Evans 1994-present
# /wiki/Gin_Blossoms 1987-1997, 2002present
# /wiki/Celine_Dion 1980-2000, 20022014, 2015
# /wiki/Take_That 1990-962005present
# /wiki/Rascal_Flatts 1999-present
# /wiki/Jennifer_Lopez 1986-present
# /wiki/No_Mercy_(pop_band) 1996-present
# /wiki/Lauryn_Hill 1993-present
# /wiki/Crazy_Town 1995-2003, 2007present
# /wiki/Dem_Franchize_Boyz 2004-2008
# /wiki/Westlife 1998-2012hiatus: 200809
# /wiki/Kelis 1997-present
# /wiki/Johnt%C3%A1_Austin 1995-present
# /wiki/Monifah 1994-present
# /wiki/Duice 1992-1995
# /wiki/Jason_Mraz 1999-present
# /wiki/Styles_P 1994-present
# /wiki/Jon_B. 1995-present
# /wiki/Journey_(band) 1973-present
# /wiki/Marky_Mark_and_the_Funky_Bunch 1989-1993
# /wiki/LFO_(group) 1995-2002, 2009
# /wiki/N.O.R.E. 1995-present
# /wiki/Brandy_Norwood 1993-present
# /wiki/Fuel_(band) 1985-present
# /wiki/4_P.M._(group) 1991--present
# /wiki/UB40 1978-present
# /wiki/Junior_M.A.F.I.A. 1994-19972005present
# /wiki/Kenny_G 1973-1982 (group)1982present
# /wiki/Robin_Thicke 1994-present
# /wiki/Lil%27_Scrappy 2002-present
# /wiki/Donna_Lewis 1996-present
# /wiki/Sean_Combs 1990-present
# /wiki/Nicole_Wray 1997-present
# /wiki/Fabolous 1998-present
# /wiki/Tim_McGraw 1990-present
# /wiki/Jamie_Foxx 1989-present
# /wiki/Samantha_Mumba 1999-Present
# /wiki/Keith_Sweat 1975-present
# /wiki/Quad_City_DJ%27s 1992-19972012-present
# /wiki/JT_Money 1989-present
# /wiki/Taylor_Swift 2004-present
# /wiki/Filter_(band) 1993-present
# /wiki/H-Town_(band) 1991-present
# /wiki/Dirty_Vegas 2001-2005; 2008present
# /wiki/Beck 1985-present
# /wiki/Boyz_II_Men 1985-present
# /wiki/Shawn_Colvin 1973-present
# /wiki/The_Heights_(TV_series) False
# /wiki/Lonestar 1992-present
# /wiki/Neon_Trees 2005- (2005)present
# /wiki/Keri_Hilson 2001-present
# /wiki/Captain_Hollywood_Project 1992-present
# /wiki/Edm%C3%A9e_Daenen 2003-present
# /wiki/Rixton_(band) 2012-present
# /wiki/Romeo_Miller 1999-present
# /wiki/Mary_J._Blige 1989-present
# /wiki/OutKast 1992-2006, 2014-present
# /wiki/Matchbox_Twenty 1995- (1995)2004, 20072008, 2010present
# /wiki/Ace_of_Base 1990-present
# /wiki/Kirko_Bangz 2009-present
# /wiki/Blessid_Union_of_Souls 1990-present
# /wiki/Tal_Bachman 1992-present
# /wiki/Paul_McCoy 2000-present
# /wiki/Shai_(band) 1992-present
# /wiki/Monica_(singer) 1993-present
# /wiki/David_Banner 1996-present
# /wiki/Beenie_Man 1979-present
# /wiki/Static_Major 1993-2008
# /wiki/Sean_Kingston 2004--present
# /wiki/Pitbull_(rapper) 2001-present
# /wiki/KWS_(band) 1992-1994
# /wiki/Tevin_Campbell 1988-present
# /wiki/Duran_Duran 1978-present
# /wiki/3LW 1999-2007
# /wiki/Nina_Sky 2003- (2003)present
# /wiki/Nick_Cannon 1998-present
# /wiki/Thrust_(rapper) 1996-present
# /wiki/Swedish_House_Mafia 2005-2013
# /wiki/Cee_Lo_Green 1994-present
# /wiki/Jessie_J 2005-present
# /wiki/Big_Mountain_(band) 1988-present
# /wiki/Ashanti_(entertainer) 1994-present
# /wiki/Sam_Hunt_(musician) 2009-present
# /wiki/Domino_(rapper) 1992-present
# /wiki/George_Clinton_(musician) 1955-present
# /wiki/Cassidy_(rapper) 2002-present
# /wiki/Yung_Berg 2001-present
# /wiki/Ying_Yang_Twins 1997-present
# /wiki/Patrick_Stump 2000-present
# /wiki/Gorillaz 1998--present
# /wiki/La_Roux 2006- (2006)present
# /wiki/Eric_Turner_(singer) 2007-present
# /wiki/Tony_Rich 1993-present
# /wiki/Rikrok 1995-present
# /wiki/Timbaland_%26_Magoo 1989-present
# /wiki/Incubus_(band) 1991-present
# /wiki/Hoobastank 1994-present
# /wiki/Nate_Dogg 1992-2011
# /wiki/Restless_Heart 1984-1994, 1998, 2002present
# /wiki/Blue_October 1995-present
# /wiki/Aaliyah 1991-2001
# /wiki/Tom_Petty 1969-present
# /wiki/Pras 1992-present
# /wiki/Hurricane_Chris_(rapper) 2006-present
# /wiki/Hinder 2001-present
# /wiki/Eternal_(band) 1992-20002013present
# /wiki/BoDeans 1983-present
# /wiki/Wayne_Wonder 1987-present
# /wiki/Tamia 1995-present
# /wiki/The_KLF 1987-1992(Reunions: 1995 and 1997)
# /wiki/Jordan_Knight 1984-present
# /wiki/The_Cranberries 1989-2003, 2009present
# /wiki/Lorde 2009-present
# /wiki/The_D.E.Y. 2006-present
# /wiki/Zac_Brown_Band 2002-present
# /wiki/The_Pussycat_Dolls 2003-10
# /wiki/Eamon_(singer) 2003-present
# /wiki/Jodeci 1988- (1988)1996, 2014present
# /wiki/OneRepublic 2002-present
# /wiki/Blink_182 1992-2005; 2009present
# /wiki/Dionne_Farris 1992-present
# /wiki/DHT_(band) 2003-present
# /wiki/Bone_Thugs-n-Harmony 1991-present
# /wiki/Jann_Arden 1992-present
# /wiki/Florida_Georgia_Line 2010-present
# /wiki/Creed_(band) 1993-2004, 20092012(hiatus)
# /wiki/Robyn 1989-present
# /wiki/Meshell_Ndegeocello 1992-present
# /wiki/Bubba_Sparxxx 1993-present
# /wiki/Fat_Joe 1992-present
# /wiki/Blues_Traveler 1987-present
# /wiki/Wale_(rapper) 2005-present
# /wiki/SWV 1990-1998, 2005present
# /wiki/CeCe_Winans 1984-present
# /wiki/Pitbull_(singer) 2001-present
# /wiki/Pretty_Ricky False
# /wiki/Mike_Jones_(rapper) 2001-present
# /wiki/General_Public 1984-1987, 19941995
# /wiki/Gillette_(singer) 1994-2004
# /wiki/Boys_Like_Girls 2005-present
# /wiki/Gavin_DeGraw 1990-present
# /wiki/Ray_J 1989-present
# /wiki/UGK 1987-2007
# /wiki/Case_(singer) 1992-present
# /wiki/Mark_Morrison 1993-present
# /wiki/Ryan_Cabrera 2004-present
# /wiki/Taylor_Hicks 1995-present
# /wiki/Lisa_Lopes 1990-2002
# /wiki/Babyface_(musician) 1976-present
# /wiki/Silkk_the_Shocker 1991-present
# /wiki/Linkin_Park 1996-present
# /wiki/Cher 1963-present
# /wiki/Scarface_(rapper) 1988-present
# /wiki/Joe_(singer) 1992-present
# /wiki/The_Killers 2001-present
# /wiki/Snap! 1989-1996; 2000; 2002present
# /wiki/Def_Leppard 1977-present
# /wiki/Macklemore 2000-present
# /wiki/Oasis_(band) 1991-2009
# /wiki/Cypress_Hill 1988-present
# /wiki/Majid_Jordan 2011-present
# /wiki/Tyga 2007-present
# /wiki/Ciara 2002-present
# /wiki/Craig_Mack 1988-present
# /wiki/The_Four_Seasons_(band) 1960-present
# /wiki/Usher_(entertainer) 1991-present
# /wiki/C%C3%A9line_Dion 1980-2000, 20022014, 2015
# /wiki/Willa_Ford 1999-present
# /wiki/Brooks_%26_Dunn 1990-2010, 2015present
# /wiki/Jessica_Simpson 1999-present
# /wiki/Ahmad_(rapper) 1992-present
# /wiki/Justin_Timberlake 1992-present
# /wiki/Jadakiss 1993-  present
# /wiki/Shakira 1990-present
# /wiki/Naughty_by_Nature 1988-20022006present
# /wiki/Debelah_Morgan False
# /wiki/Alex_Band 2000-present
# /wiki/Joey_McIntyre 1985-present
# /wiki/B.o.B 2006-present
# /wiki/Green_Day 1986-present
# /wiki/Calvin_Harris 2002-present
# /wiki/Clay_Aiken 2003-present
# /wiki/Heavy_D False
# /wiki/Jason_Weaver False
# /wiki/Real_McCoy_(band) 1988-present
# /wiki/Missy_Elliott 1991-present
# /wiki/Chingy 1997-Present
# /wiki/Shontelle 2008-present
# /wiki/Annie_Lennox 1976-present
# /wiki/Lana_Del_Rey 2005-present
# /wiki/Tupac_Shakur 1989-1996
# /wiki/Blaque 1996-2005,2012-present
# /wiki/50_Cent 1998-present
# /wiki/Meredith_Brooks 1989-2007 (as artist)
# /wiki/Eve_(entertainer) 1998-present
# /wiki/KONGOS 2007- (2007)present
# /wiki/Wanz 1978-present
# /wiki/Foo_Fighters 1994- (1994)present
# /wiki/Darryl_Worley 1999-present
# /wiki/Lenny_Kravitz 1988-present
# /wiki/5_Seconds_of_Summer 2011-present
# /wiki/Sister_Hazel 1993-present
# /wiki/Asher_Roth 2005-present
# /wiki/Brad_Paisley 1999-present
# /wiki/Jay-Z 1993-present
# /wiki/Shop_Boyz 2004--present
# /wiki/Sisqo 1992-present
# /wiki/Jesse_Powell 1993-present
# /wiki/Christina_Perri 2010-present
# /wiki/Janet_Jackson 1973-present
# /wiki/Flo_Rida 2006-present
# /wiki/Afrojack 2004-present
# /wiki/Toby_Keith 1993-present
# /wiki/Jimmy_Eat_World 1993-present
# /wiki/Thomas_Rhett 2010-present
# /wiki/Robin_S. 1992-present
# /wiki/G-Unit 1999-present
# /wiki/John_Michael_Montgomery 1991-present
# /wiki/Kelly_Rowland 1997-present
# /wiki/Tina_Turner 1958-present
# /wiki/Blu_Cantrell 2001-present
# /wiki/Saving_Abel 2004-present
# /wiki/Jermaine_Dupri 1984-present
# /wiki/FireHouse_(band) 1989-present
# /wiki/Ya_Kid_K False
# /wiki/Lifehouse_(band) 1999-present
# /wiki/Alice_Deejay 1998-2002; 2014-Present
# /wiki/Iggy_Azalea 2011-present
# /wiki/The_Verve_Pipe 1992- (1992)present
# /wiki/Weezer 1992-present
# /wiki/Enigma_(musical_project) 1990-present
# /wiki/Savage_Garden 1993-2001
# /wiki/Juelz_Santana 1995-present
# /wiki/The_Smashing_Pumpkins 1988-2000, 2006present
# /wiki/Omarion 1990-, 1999present
# /wiki/Fun_(band) 2008-2015 (hiatus)
# /wiki/Wiz_Khalifa 2005-present
# /wiki/Prince_(entertainer) 1976-present
# /wiki/Color_Me_Badd 1987- (1987)-2000, 2011-present
# /wiki/B2K 1998-2004
# /wiki/Gnarls_Barkley 1999--present
# /wiki/Edwin_McCain 1991-present
# /wiki/Ruff_Endz 1994- (1994)present
# /wiki/DRS_(group) 1992- -present
# /wiki/Lil%27_Kim 1994-present
# /wiki/U2_(band) 1976-present
# /wiki/Luniz 1994-Present
# /wiki/Florence_Welch 2006-present
# /wiki/Mia_X 1992-present
# /wiki/Daniel_Bedingfield 2001-05, 2007present
# /wiki/Huey_(rapper) 2006-present
# /wiki/Little_Big_Town 1998-present
# /wiki/Clean_Bandit 2009-present
# /wiki/The_Neighbourhood 2011-present
# /wiki/Twista 1989-present
# /wiki/Billie_Myers 1997-present
# /wiki/Janelle_Mon%C3%A1e 2003-present
# /wiki/Juvenile_(rapper) 1991-present
# /wiki/Tom_Petty_and_the_Heartbreakers 1976-present
# /wiki/Chant%C3%A9_Moore 1986-present
# /wiki/Nick_Lachey 1995-present
# /wiki/Ylvis 2000-present
# /wiki/J._Cole 2007-present
# /wiki/Technotronic 1988-2000
# /wiki/Gloria_Estefan 1977-present
# /wiki/White_Town 1989-present
# /wiki/Kandi_Burruss 1993-present
# /wiki/Tag_Team_(group) 1993-1995
# /wiki/Ol%27_Dirty_Bastard 1989-2004
# /wiki/Carrie_Underwood 2005-present
# /wiki/Tinie_Tempah 2005-present
# /wiki/Keyshia_Cole 2004-present
# /wiki/Metro_Station_(band) 2006-present
# /wiki/Colby_O%27Donis 2008-present
# /wiki/Sara_Bareilles 2002-present
# /wiki/Panic!_at_the_Disco 2004-present
# /wiki/Guns_N%27_Roses 1985-present
# /wiki/4_Non_Blondes 1989-1994, 2014
# /wiki/Big_Tymers 1996-2005
# /wiki/Beyonc%C3%A9 1997-present
# /wiki/DJ_Frank_E 2002-present
# /wiki/Baby_Boy_da_Prince 2002-present
# /wiki/Sacario 2001-  present
# /wiki/Rod_Stewart 1961-present
# /wiki/Angie_Martinez 1996-present
# /wiki/Webbie 2000- Present
# /wiki/Murphy_Lee 1995-present
# /wiki/Natasha_Bedingfield 2003-present
# /wiki/Aretha_Franklin 1956-present
# /wiki/Mark_Chesnutt 1988-present
# /wiki/Mase 1993-1999200320072009present
# /wiki/Kristinia_DeBarge 2003-present
# /wiki/%27N_Sync 1995-2002
# /wiki/Ludacris 1997-present
# /wiki/The_Lumineers 2002-present
# /wiki/TQ_(singer) 1990-present
# /wiki/Jeezy 2000-present
# /wiki/Sophie_B._Hawkins 1992-present
# /wiki/Train_(band) 1993-2006, 2009-present
# /wiki/Crime_Mob 2004-Present
# /wiki/Cheb_Mami 1982-  present
# /wiki/Craig_David 1999-present
# /wiki/Fatman_Scoop 1997-present
# /wiki/Destiny%27s_Child 1990- (1990)2006 (2006)
# /wiki/Darius_Rucker 1986-present
# /wiki/St._Lunatics 1993-present
# /wiki/Neon_Hitch 2009-present
# /wiki/I-20_(rapper) 2000-present
# /wiki/Tears_for_Fears 1981-present
# /wiki/Eagle-Eye_Cherry 1997-2003, 2012
# /wiki/Young_Jeezy 2000-present
# /wiki/Eli_Young_Band 2000-present
# /wiki/Paula_DeAnda 2006-present
# /wiki/Kelly_Price 1992-Present
# /wiki/Roscoe_Dash 2009-present
# /wiki/Planet_Soul False
# /wiki/Evan_and_Jaron 1994- ~ 2008
# /wiki/Aerosmith 1970-present
# /wiki/10,000_Maniacs 1981-present
# /wiki/Kevin_McCall 2007-present
# /wiki/Avril_Lavigne 1999-present
# /wiki/Bobby_V 1996-present
# /wiki/Elton_John 1964-present
# /wiki/L.V._(singer) 1991-present
# /wiki/Dixie_Chicks 1989-present
# /wiki/Future_(rapper) 2009-present
# /wiki/Taylor_Dayne 1985-present
# /wiki/Sean_Paul 1997--present
# /wiki/Bobby_Brown 1979-present
# /wiki/69_Boyz 1992-present
# /wiki/Digable_Planets 1992-199520052011[1]
# /wiki/Havana_Brown_(musician) 2008-present
# /wiki/Go_West_(band) 1982-present
# /wiki/Pussycat_Dolls 2003-10
# /wiki/George_Michael 1981-present
# /wiki/D12 1996-present
# /wiki/Bun_B 1987-present
# /wiki/Hellogoodbye 2001-present
# /wiki/Randy_Houser 2004-present
# /wiki/Culture_Beat 1989-present
# /wiki/Genesis_(band) 1967-982006present
# /wiki/Dwele 2000-present
# /wiki/Coldplay 1996-present
# /wiki/Soul_Asylum 1981-present
# /wiki/Idina_Menzel 1996-present
# /wiki/House_of_Pain 1991-199620102011
# /wiki/Sammie 1999-present
# /wiki/Dr._Dre 1984-present
# /wiki/Chad_Kroeger 1995-present
# /wiki/Jimmy_Page 1957-present
# /wiki/Larry_Mullen,_Jr. 1976-present
# /wiki/Elliott_Yamin 2006-present
# /wiki/Eve_6 1995-2004, 2007present
# /wiki/Patty_Smyth 1981-present
# /wiki/Lloyd_Banks 1999-present
# /wiki/Mr._Big_(band) 1988-2002, 2009present
# /wiki/Vertical_Horizon 1991-present
# /wiki/Rivers_Cuomo 1984-present
# /wiki/Justin_Bieber 2008-present
# /wiki/Len_(band) 1991- (1991)present
# /wiki/Goo_Goo_Dolls 1986-present
# /wiki/Miguel_(singer) 1998-present
# /wiki/Sia_Furler 1993-present
# /wiki/The_Verve 1990-1995, 19971999, 20072009
# /wiki/Tracy_Chapman 1986-present
# /wiki/Santana_(band) 1967-present
# /wiki/Paramore 2004-present
# /wiki/Jibbs 2006-present
# /wiki/Raphael_Saadiq 1983-present
# /wiki/Nicki_French 1992-present
# /wiki/Brantley_Gilbert 2005-present
# /wiki/Carl_Thomas_(singer) 1994-present
# /wiki/Lily_Allen 2002-present
# /wiki/Metallica 1981-present
# /wiki/Monica_(entertainer) 1993-present
# /wiki/Lil_Jon 1993-present
# /wiki/Loon_(rapper) 1998-2009
# /wiki/Puddle_of_Mudd 1991-present
# /wiki/Brandy_(entertainer) 1993-present
# /wiki/La_Bouche 1994-2002; 2015
# /wiki/Xscape_(band) 1991-2000
# /wiki/R._Kelly 1989-present
# /wiki/Diddy_%E2%80%93_Dirty_Money 2007-2012
# /wiki/Truth_Hurts 1992-present
# /wiki/MC_Hammer 1985-Present
# /wiki/Chris_Brown_(American_singer) 2005-present
# /wiki/Master_P 1990-present
# /wiki/Hanson_(band) 1992-present
# /wiki/Joey_Lawrence 1982-present
# /wiki/Icona_Pop 2009-present
# /wiki/Lady_Saw 1994-present
# /wiki/Gavin_Rossdale 1983-present
# /wiki/Lupe_Fiasco 2000-present
# /wiki/The_Black_Eyed_Peas 1992-present
# /wiki/Timbaland 1990-present
# /wiki/Groove_Theory 1993-2001, 2010present
# /wiki/LL_Cool_J 1984-present
# /wiki/The_Fray_(band) 2002-present
# /wiki/Seal_(musician) 1987-present
# /wiki/Mumford_%26_Sons 2007-present
# /wiki/Bon_Jovi 1983-present
# /wiki/Mo_Thugs 1995-2009
# /wiki/Lloyd_(singer) 1996-present
# /wiki/The_Script 2001-present
# /wiki/John_Legend 2000-present
# /wiki/Dave_Matthews_Band 1991-present
# /wiki/Nickelback 1995-present
# /wiki/8Ball_%26_MJG 1991-present
# /wiki/Do_or_Die_(group) 1995-present
# /wiki/Das_EFX 1989-present
# /wiki/New_Boyz 2009-2013; 2014
# /wiki/Nirvana_(band) 1987-1994
# /wiki/Kelly_Clarkson 2002-present
# /wiki/Leona_Lewis 2001-present
# /wiki/Cherish_(band) 2003-present
# /wiki/Mr_Hudson 2006-present
# /wiki/Ellie_Goulding 2008-present
# /wiki/Nico_%26_Vinz 2009-present
# /wiki/Estelle_(musician) 2004-present
# /wiki/Jet_(band) 2001-2012
# /wiki/Positive_K 1986-present
# /wiki/Los_del_R%C3%ADo 1962-present
# /wiki/Gotye 2001-present
# /wiki/Sixpence_None_the_Richer 1992-2004, 2008present
# /wiki/The_Cataracs 2003--Present
# /wiki/Jade_(American_band) 1991-1997, 2014-present
# /wiki/Peabo_Bryson 1976-present
# /wiki/Mokenstef 1994-2000
# /wiki/Amy_Grant 1976-present
# /wiki/Travis_Tritt 1989-  present
# /wiki/Bounty_Killer 1992-present
# /wiki/Birdman_(rapper) 1989-present
# /wiki/Of_Monsters_and_Men 2010-present
# /wiki/Joe_Public_(band) 1989-present
# /wiki/Rich_Homie_Quan 2012-present
# /wiki/Jerrod_Niemann 1999-present
# /wiki/Hayley_Williams 2003-present
# /wiki/Adam_Clayton 1976-present
# /wiki/Pearl_Jam 1990- (1990)present
# /wiki/Emeli_Sand%C3%A9 2008-present
# /wiki/Baauer 2002-present
# /wiki/Michael_Franti 1986-present
# /wiki/Soulja_Slim 1992-2003
# /wiki/Imagine_Dragons 2008-present
# /wiki/Willie_Nelson 1956-present
# /wiki/Sam_Smith_(singer) 2007-present
# /wiki/The_Red_Jumpsuit_Apparatus 2003-present
# /wiki/Karmin 2010-present
# /wiki/Cory_Gunz 2003-present
# /wiki/Fall_Out_Boy 2001-2009, 2013present
# /wiki/Matthew_Santos 2006-present
# /wiki/Kris_Allen 2007-present
# /wiki/Sugar_Ray 1986-present
# /wiki/Diamond_Rio 1982-present
# /wiki/Gente_de_Zona 2000-present
# /wiki/The_Blackout_All-Stars 1994
# /wiki/Jake_Owen 2004-present
# /wiki/Jordin_Sparks 2007-present
# /wiki/Pharrell_Williams 1992-present
# /wiki/Coolio 1987-present
# /wiki/Nitti_(producer) 2000--present
# /wiki/Owl_City 2007-present
# /wiki/Vanessa_L._Williams 1983-present
# /wiki/Edward_Maya 2006-present
# /wiki/DJ_Kool 1979-present
# /wiki/Jonas_Brothers 2005-13
# /wiki/Jewel_(singer) 1994-present
# /wiki/Green_Jell%C3%BF 1981-19952008present
# /wiki/Five_(band) 1997-2001, 2006072012present
# /wiki/Deborah_Cox 1995-present
# /wiki/Will_Smith 1985-present
# /wiki/Jeremy_Jordan_(singer) 1992-present
# /wiki/Mr._Cheeks 1991-present
# /wiki/Salt-n-Pepa 1985-20022007present
# /wiki/Des%27ree 1990-2003
# /wiki/Brownstone_(group) 1994-1997; 2000
# /wiki/Christina_Aguilera 1991-present
# /wiki/Frankie_J 2000- present
# /wiki/Papa_Roach 1993- (1993)present
# /wiki/Rihanna 2005-present
# /wiki/Kevin_Lyttle 2001-present
# /wiki/Bad_Meets_Evil 1997--2003, 2011-present
# /wiki/Disclosure_(band) 2010-present
# /wiki/Natalie_Merchant 1981-present
# /wiki/Jess_Glynne 2012-present
# /wiki/Olly_Murs 2009-present
# /wiki/Erykah_Badu 1996-present
# /wiki/Niia False
# /wiki/Erick_Sermon 1987-present
# /wiki/Gretchen_Wilson 2004-present
# /wiki/Thompson_Square 2002-present
# /wiki/Rich_Boy 1999-  present
# /wiki/Too_Short 1981-present
# /wiki/Kenny_Chesney 1993-present
# /wiki/Keith_Urban 1991-present
# /wiki/Nayer 2002--present
# /wiki/Nelly 1993-present
# /wiki/MC_Lyte 1986-present
# /wiki/Jessica_Andrews 1998-2008
# /wiki/20_Fingers 1994-1995 (as artist)1996Present (as producers)
# /wiki/Lord_Tariq_and_Peter_Gunz 1996-1999
# /wiki/Do_(singer) 2000-present
# /wiki/Freak_Nasty 1994--present
# /wiki/K-Ci_%26_JoJo 1990-present
# /wiki/Amerie 2001-present
# /wiki/The_LOX 1994-present
# /wiki/Sleepy_Brown 1995-present
# /wiki/Wreckx-n-Effect 1987-1996; 2014-present
# /wiki/Shanice 1984-present
# /wiki/The_Isley_Brothers 1954-present
# /wiki/Chamillionaire 1997-present
# /wiki/Toni_Braxton 1989-present
# /wiki/Spin_Doctors 1988-99, 2001present
# /wiki/Jennifer_Paige 1995-present
# /wiki/Passenger_(singer) 2003-present
# /wiki/Lady_Gaga 2001-present
# /wiki/Sons_of_Funk 1997-1999, 2014-present
# /wiki/Nine_Days 1994-present
# /wiki/Barbra_Streisand 1955-present
# /wiki/Jay_Z 1993-present
# /wiki/Somethin%27_for_the_People 1990-2000
# /wiki/Shania_Twain 1992-  present
# /wiki/Ariana_Grande 2008-present
# /wiki/Ghost_Town_DJ%27s 1995-1997
# /wiki/Floetry 1997-2005, 2015-present
# /wiki/Brian_McKnight 1988-present
# /wiki/Evanescence 1995-present
# /wiki/Mikky_Ekko 2008-present
# /wiki/The_Calling 1999-2005,[4] 2013-Present
# /wiki/Kimbra 2000-present
# /wiki/Gabrielle_(singer) 1993-present
# /wiki/Ugly_Kid_Joe 1987-1997, 2010present
# /wiki/Jade_(American_group) 1991-1997, 2014-present
# /wiki/Josey_Scott False
# /wiki/Kid_Rock 1990-present
# /wiki/David_Cook_(singer) 1999-present
# /wiki/Will.i.am False
# /wiki/Young_Thug 2011-present
# /wiki/Mario_Winans 1995-present
# /wiki/Jason_Derulo 2006-present
# /wiki/Gym_Class_Heroes 1997-present
# /wiki/Erasure 1985-present
# /wiki/Luther_Campbell 1985-2006 (as rapper)present
# /wiki/Lil_Boosie 1996-present
# /wiki/Miranda_Lambert 2001-present
# /wiki/Chad_Brock 1998-present
# /wiki/Michael_Jackson 1964-2009
# /wiki/Kesha 2005-present
# /wiki/Nas 1991-present
# /wiki/Blake_Shelton 2001-present
# /wiki/Jo_Dee_Messina 1996-present
# /wiki/Marc_Anthony 1988-present
# /wiki/Zhan%C3%A9 1993-1999
# /wiki/Ruben_Studdard 2003-present
# /wiki/Mims_(rapper) 2001--present
# /wiki/All-4-One 1993-present
# /wiki/KT_Tunstall 2000-present
# /wiki/The_Pretenders 1978-present
# /wiki/Rita_Ora 2007-present
# /wiki/J-Kwon 2003-present
# /wiki/Phil_Collins 1968-2011
# /wiki/Fiend_(rapper) 1994-present
# /wiki/Steve_Holy 1999-present
# /wiki/Naughty_Boy 2005-present
# /wiki/BJ_the_Chicago_Kid 2000-s-present
# /wiki/No_Doubt 1986-present
# /wiki/Lauren_Bennett 2007-present
# /wiki/Marvin_Gaye 1959-1984
# /wiki/Magic! 2012- (2012)present
# /wiki/Dishwalla 1994-2006, 2008-present
# /wiki/Van_Halen 1972-present
# /wiki/Hollis_(singer) 2013-present
# /wiki/Christina_Milian 1996-present
# /wiki/Staind 1995- (1995)2012, 2014
# /wiki/Blinky_Blink 1998-present
# /wiki/Ini_Kamoze 1981-present
# /wiki/Tom_Cochrane 1973-present
# /wiki/George_Strait 1976-present
# /wiki/City_High 1999-2003
# /wiki/Ray_Dalton 2011--present
# /wiki/Outkast 1992-2006, 2014-present
# /wiki/Rednex 1994-2002, 2006present
# /wiki/DMX_(rapper) 1988-present
# /wiki/The_Fray 2002-present
# /wiki/Trillville 1997-present
# /wiki/American_Authors 2006-present
# /wiki/TLC_(band) 1990-present
# /wiki/T.I. 1996-present
# /wiki/Sting_(musician) 1971-present
# /wiki/Nivea_(singer) 2000-present
# /wiki/Leighton_Meester 1999-present
# /wiki/French_Montana 2002-present
# /wiki/Madonna_(entertainer) 1979-present
# /wiki/Selena_Gomez 2002-present
# /wiki/Barenaked_Ladies 1988-present
# /wiki/Wyclef_Jean 1993-present
# /wiki/Young_Buck 1995-present
# /wiki/New_Edition 1982-1990199619972002present
# /wiki/Queen_Latifah 1988-present
# /wiki/Arrested_Development_(group) 1988-1996, 2000present
# /wiki/City_Spud 1995-present
# /wiki/Selena_Gomez_%26_the_Scene 2008-2012 (on hiatus)
# /wiki/Amy_Winehouse 2003-2011
# /wiki/Duncan_Sheik 1993--present
# /wiki/Ginuwine 1994-present
# /wiki/Changing_Faces_(group) 1993-present
# /wiki/Busta_Rhymes 1988-present
# /wiki/Charli_Baltimore 1995-present
# /wiki/Cash_Out 2012-present
# /wiki/Diana_King 1993-present
# /wiki/Maroon_5 1994-present
# /wiki/Snoop_Dogg 1992-present
# /wiki/Vika_Jigulina 2000-present
# /wiki/JoJo_(singer) 1998-present
# /wiki/Kid_Ink 2005-present
# /wiki/Capital_Cities_(band) 2010-present
# /wiki/Katy_Perry 2000-present
# /wiki/Petey_Pablo 1995-present
# /wiki/Default_(band) 1999-2013 (Hiatus)
# /wiki/Paula_Abdul 1978-present
# /wiki/Psy 1999-present
# /wiki/Dierks_Bentley 1994-present
# /wiki/Alejandro_Sanz 1989-present
# /wiki/Chris_Brown 2005-present
# /wiki/Trace_Adkins 1995-present
# /wiki/Eiffel_65 1998-2005, 2010present
# /wiki/Hootie_%26_the_Blowfish 1986-2008 (fully active)2008-present
# /wiki/Young_Money_Entertainment False
# /wiki/Howie_Day 1998-present
# /wiki/Adina_Howard 1994-present
# /wiki/Hunter_Hayes 2000-present
# /wiki/Enrique_Iglesias 1994-present
# /wiki/Mint_Condition 1984-present
# /wiki/Cam%27ron 1993-present
# /wiki/Michelle_Branch 1998-present
# /wiki/Merril_Bainbridge 1977-2003, 2015-present
# /wiki/Fort_Minor 2004-2006, 2015present
# /wiki/Cascada 2004-present
# /wiki/Ali_%26_Gipp 2005-2007
# /wiki/A_Great_Big_World 2011-present
# /wiki/Everything_but_the_Girl 1982-2000
# /wiki/Taio_Cruz 2006-present
# /wiki/Norah_Jones 2001-present
# /wiki/Sarah_McLachlan 1988-present
# /wiki/Right_Said_Fred 1989-present
# /wiki/Sylk-E._Fyne 1995-  Present
# /wiki/Luscious_Jackson 1991-2000, 2011present
# /wiki/Bryan_Adams 1976-present
# /wiki/E-40 1990-present
# /wiki/Snow_Patrol 1994-present
# /wiki/Shaggy_(musician) 1993-present
# /wiki/ASAP_Rocky 2007-present
# /wiki/Avicii 2007-present
# /wiki/Ja_Rule 1993-present
# /wiki/Sheryl_Crow 1985-present
# /wiki/Spice_Girls 1994-20002007082012
# /wiki/Cameo_(band) 1974-present
# /wiki/Dru_Hill 1992-present
# /wiki/Michael_Bubl%C3%A9 1996-present
# /wiki/Alan_Jackson 1983-present
# /wiki/Corona_(group) 1993-  present
# /wiki/Yanou 1997-  present
# /wiki/Gwen_Stefani 1986-present
# /wiki/Thal%C3%ADa 1979-present
# /wiki/Iyaz 2009-present
# /wiki/Trey_Songz 2004-present
# /wiki/Lil%27_Flip 1997-present
# /wiki/Buckcherry 1995-2002, 2005present
# /wiki/Gucci_Mane 2001-present
# /wiki/Soulja_Boy 2005-present
# /wiki/Sasha_(deejay) 1992-present
# /wiki/Eric_Clapton 1962-present
# /wiki/Dobie_Gray 1960-2011
# /wiki/Wynter_Gordon 2007-present
# /wiki/Fergie_(singer) 1984-present
# /wiki/Luther_Vandross 1972-2005
# /wiki/M.I.A._(rapper) 2000-present
# /wiki/John_Mellencamp 1976-present
# /wiki/David_Guetta 1984-present
# /wiki/Unk 1998-present
# /wiki/Sean_Garrett 2001-present
# /wiki/The_Proclaimers 1983-present
# /wiki/DJ_Snake 2009-present
# /wiki/Marcy_Playground 1996-present
# /wiki/Bravehearts 1998-present
# /wiki/ScHoolboy_Q 2007-present
# /wiki/Jonah_Matranga 1991-present
# /wiki/Mystikal 1993-present
# /wiki/Enya 1980-present
# /wiki/Kings_of_Leon 2000-present
# /wiki/Kid_Cudi 2003-present
# /wiki/Bow_Wow_(rapper) 1993-present
# /wiki/James_Blunt 2003-present
# /wiki/Ashlee_Simpson 2001-present
# /wiki/Plain_White_T%27s 1997-present
# /wiki/Switchfoot 1996-present
# /wiki/Lisa_Loeb 1989-present
# /wiki/Kevin_Rudolf 2000- - present
# /wiki/Shakespears_Sister 1988-1996, 2009present
# /wiki/Orianthi 1997-present
# /wiki/Wanya_Morris 1988-present
# /wiki/Big_Sean 2007-present
# /wiki/Tiara_Thomas 2009-present
# /wiki/Shawnna 1996-present
# /wiki/Eden%27s_Crush 2001-2002
# /wiki/Atlantic_Starr 1976-present
# /wiki/Tyrese_Gibson 1994-present
# /wiki/3T 1989-2005, 2013present
# /wiki/J._Holiday 2006--present
# /wiki/Cherine_Anderson 2006-present
# /wiki/Foxy_Brown_(rapper) 1994-present
# /wiki/Jaheim 1996-present
# /wiki/Mario_(entertainer) 2001-present
# /wiki/John_Martin_(singer) 2010-present
# /wiki/Everlast_(musician) 1989-present
# /wiki/The_All-American_Rejects 1999-present
# /wiki/Anna_Kendrick 1998-present
# /wiki/Aaron_Hall_(musician) 1988--present
# /wiki/Allure_(group) 1996-present
# /wiki/Aloe_Blacc 1995-present
# /wiki/2_Chainz 1997-present
# /wiki/The_Band_Perry 2005-present
# /wiki/Syleena_Johnson 1997-present
# /wiki/Foxes_(singer) 2011-present
# /wiki/Macklemore_%26_Ryan_Lewis 2008-present
# /wiki/Alabama_(band) 1969--2004, 2006-2007, 2010-present
# /wiki/Martin_Page 1981-present
# /wiki/Paula_Cole 1992-present
# /wiki/The_Click_Five 2003-2013
# /wiki/Faith_Hill 1993-present
# /wiki/Tony!_Toni!_Ton%C3%A9! 1988-19972003-present
# /wiki/Pistol_Annies 2011-2013 (on hiatus)
# /wiki/Toad_the_Wet_Sprocket 1986-1998, 2002, 2006present
# /wiki/Regina_Belle 1985-present
# /wiki/Skee-Lo 1985-present
# /wiki/Jagged_Edge_(band) 1995-present
# /wiki/Dino_(singer) 1988-1993
# /wiki/BBMak 1997-2003
# /wiki/C%C3%A9dric_Gervais False
# /wiki/Blackstreet 1991-present
# /wiki/Backstreet_Boys 1993-present
# /wiki/Billy_Ray_Cyrus 1990-present
# /wiki/M%C3%BDa 1996-present
# /wiki/Lil_Phat 2007-2012
# /wiki/Bobby_Shmurda 2014-present
# /wiki/Nicki_Minaj 2004-present
# /wiki/Redman_(rapper) 1990-present
# /wiki/Mariah_Carey 1988-present
# /wiki/Los_Lonely_Boys 1996-present
# /wiki/Del_Amitri 1983-2002, 2013present
# /wiki/Moby 1984-present
# /wiki/Meat_Loaf 1970-present
# /wiki/Beyonc%C3%A9_Knowles 1997-present
# /wiki/Terror_Squad_(group) 1998-2006
# /wiki/Kendrick_Lamar 2003-present
# /wiki/Pusha_T 1992-present
# /wiki/LMFAO 2006-12 (on hiatus)
# /wiki/Third_Eye_Blind 1993-present
# /wiki/Citizen_King 1993-2002
# /wiki/Sabi_(singer) 2008-present
# /wiki/Cali_Swag_District 2010--present
# /wiki/Peter_Cetera 1962-present
# /wiki/Inner_Circle_(reggae_band) 1968-present
# /wiki/Trapt 1995-present
# /wiki/Onyx_(group) 1988-present
# /wiki/Billy_Joel 1965-present
# /wiki/Trick_Daddy 1996-present
# /wiki/DJ_Jazzy_Jeff_%26_The_Fresh_Prince 1985-19941999 (Partial reunion) 2005 (reunion) 2013 (reunion)
# /wiki/Teddy_Geiger 2005-present
# /wiki/112_(band) 1991-present
# /wiki/Meghan_Trainor 2009-present
# /wiki/Daniel_Powter 2000-present
# /wiki/Mike_Posner 2009-present
# /wiki/Sir_Mix-a-Lot 1986-2003, 2010present
# /wiki/Skylar_Grey 2004-present
# /wiki/Jason_Aldean 2005-present
# /wiki/Az_Yet 1989-present
# /wiki/Hot_Chelle_Rae 2005-present
# /wiki/Charlie_Wilson_(singer) 1972-present
# /wiki/Young_Dro 1999-present
# /wiki/Kip_Moore 2008-present
# /wiki/Drake_(entertainer) 2001-present
# /wiki/Mary_Mary 1998-present
# /wiki/Melissa_Etheridge 1985-present
# /wiki/Amber_(performer) 1990-present
# /wiki/Lee_Brice 2007-present
# /wiki/Jay_Sean 1999-present
# /wiki/Cobra_Starship 2005- (2005)present
# /wiki/Amil_(rapper) 1994--present
# /wiki/Eminem 1992-present
# /wiki/Red_Hot_Chili_Peppers 1983- (1983)present
# /wiki/Uncle_Kracker 1987-present
# /wiki/Snow_(musician) 1989-present
# /wiki/Ryan_Lewis 2006-present
# /wiki/Tinashe 2000-present
# /wiki/Ron_Browz 1998--present
# /wiki/GoonRock 2009-present
# /wiki/Us3 1992-present
# /wiki/David_Archuleta 2003-present
# /wiki/Andr%C3%A9_3000 1991-present
# /wiki/Q-Tip_(rapper) 1988-present
# /wiki/Becky_G False
# /wiki/Richard_Marx 1980-present
# /wiki/Lee_Ann_Womack 1992-present
# /wiki/Mike_WiLL_Made-It 2005-present
# /wiki/Holly_Brook 2004-present
# /wiki/Paul_Wall 1998-present
# /wiki/Kris_Kross 1992-2013
# /wiki/Ed_Sheeran 2005-present
# /wiki/Colbie_Caillat 2007-present
# /wiki/Everclear_(band) 1991-present
# /wiki/Ace_Hood 2006-present
# /wiki/Killer_Mike 1999-present
# /wiki/Nelly_Furtado 1996-present
# /wiki/Echosmith 2009-present
# /wiki/Eric_Church 2004-present
# /wiki/Zedd_(musician) 2002-present
# /wiki/Musiq_Soulchild 1998-present
# /wiki/One_Direction 2010-present
# /wiki/Rodney_Atkins 1996-19972002present
# /wiki/The_New_Power_Generation 1990-present
# /wiki/Trina_%26_Tamara 1990-s
# /wiki/95_South 1993-2000
# /wiki/Secondhand_Serenade 2004-present
# /wiki/Silk_(group) 1989-present
# /wiki/Freekey_Zekey 1998-present
# /wiki/Awolnation 2009-present
# /wiki/SoulDecision 1993-2005
# /wiki/The_Notorious_B.I.G. 1992-1997
# /wiki/Cher_Lloyd 2010-present
# /wiki/Plies_(rapper) 2004-present
# /wiki/The_Cure 1976-present
# /wiki/Five_for_Fighting 1997-present
# /wiki/Ice_Cube 1984-present
# /wiki/Baby_Bash 1995-present
# /wiki/Alicia_Keys 1996-present
# /wiki/Queen_(band) 1970-present
# /wiki/Athena_Cage False
# /wiki/Rob_Thomas_(musician) 1995-present
# /wiki/Rocko_(rapper) 2007-present
# /wiki/Ryan_Tedder 1999-present
# /wiki/Big_Boi 1992-present
# /wiki/MKTO 2012-present
# /wiki/Grace_Potter_and_the_Nocturnals 2002- (2002)present
# /wiki/Far_East_Movement 2003-present
# /wiki/Game_(rapper) 2002-present
# /wiki/Michael_Bolton 1975-present
# /wiki/U2 1976-present
# /wiki/Lou_Bega 1988-present
# /wiki/Phillip_Phillips 2009-present
# /wiki/Daft_Punk 1993- (1993)present
# /wiki/Vanessa_Carlton 1998-present
# /wiki/Dream_(American_group) 1998-2003, 2015-present
# /wiki/Mary_Lambert_(singer-songwriter) 2011-present
# /wiki/Houston_(singer) 2004-present
# /wiki/Polow_da_Don 1999--present
# /wiki/Da_Brat 1991-present
# /wiki/2_Pistols 2006-present
# /wiki/Dev_(singer) 2010-present
# /wiki/Haddaway 1992-present
# /wiki/Whitney_Houston 1977-2012
# /wiki/DJ_Sammy 1984-present
# /wiki/Expos%C3%A9_(group) 1984-1996, 2003, 2006present
# /wiki/Chumbawamba 1980-2012
# /wiki/YoungBloodZ 1997-present
# /wiki/Descemer_Bueno 1990-present
# /wiki/Tay_Dizm 2004- - present
# /wiki/Method_Man 1992-present
# /wiki/Jimmy_Cliff 1962-present
# /wiki/Carly_Rae_Jepsen 2007-present
# /wiki/DJ_Khaled 1998-present
# /wiki/Alex_Clare 2010-present
# /wiki/3OH!3 2004-present
# /wiki/Lil_Wayne 1996-present
# /wiki/Demi_Lovato 2002-present
# /wiki/YG_(rapper) 2006-present
# /wiki/Collective_Soul 1992-present
# /wiki/Bastille_(band) 2010-present
# /wiki/Slim_Thug 1998-present
# /wiki/Mannie_Fresh 1987-present
# /wiki/Drake_(rapper) 2001-present
# /wiki/My_Chemical_Romance 2001-2013
# /wiki/Natalie_(singer) 2001--2012
# /wiki/Pink_(singer) 1995-present
# /wiki/Lil%27_Mo 1998-present
# /wiki/Luke_Bryan 2007-present
# /wiki/After_7 1987--1997; 2006-present
# /wiki/Sugarland 2002-present
# /wiki/Travie_McCoy 1997-present
# /wiki/Kool_Moe_Dee 1976-present
# /wiki/Rakim 1985-present
# /wiki/Lady_Antebellum 2006-present
# /wiki/Daddy_Yankee 1990-present
# /wiki/Cassie_(singer) 2002-present
# /wiki/John_Mayer 1998-present
# /wiki/P.M._Dawn 1988-present
# /wiki/Rick_Ross 2001-present
# /wiki/Lil_Zane 1993-present
# /wiki/Crystal_Waters 1987-present
# /wiki/Mobb_Deep 1992--2012, 2013-present
# /wiki/Jeremih 2008-present
# /wiki/Young_Money False
# /wiki/Maxwell_(musician) 1991-2002, 2009-present
# /wiki/Toya_(singer) 2001-2006
# /wiki/The-Dream 2001-present
# /wiki/INOJ 1997-present
# /wiki/Young_Gunz 1995-present
# /wiki/Danity_Kane 2005-09, 201314
# /wiki/Nate_Ruess 2001-present
# /wiki/Krayzie_Bone 1991-present
# /wiki/Macy_Gray 1988-present
# /wiki/Boy_Krazy 1991-1993
# /wiki/3_Doors_Down 1996-present
# /wiki/Bruno_Mars 2004-present
# /wiki/The_Wanted 2009-present
# /wiki/Martin_Garrix 2012-present
# /wiki/Prince_(musician) 1976-present
# /wiki/Lumidee 2003-present
# /wiki/Waka_Flocka_Flame 2008-present
# /wiki/Sisq%C3%B3 1992-present
# /wiki/Charli_XCX 2008-present
# /wiki/Brooke_Valentine 2004-present
# /wiki/Adam_Levine 1994-present
# /wiki/Akon 1996-present
# /wiki/Son_by_Four 1997-20012003present
# /wiki/Smash_Mouth 1994-present

# %%
tempdf=pd.DataFrame(singer_band_info_list)
tempdf.head()
# Out:
#          born                                             genres                       url            ya
# 0       False  [/wiki/Rock_music, /wiki/Pop_rock, /wiki/Post-...     /wiki/Daughtry_(band)  2006-present
# 1       False                           [/wiki/Rhythm_and_blues]        /wiki/Ronald_Isley  1954-present
# 2  1976-01-28                              [/wiki/Hip_hop_music]  /wiki/Rick_Ross_(rapper)  2001-present
# 3  1992-11-23                                  [/wiki/Pop_music]         /wiki/Miley_Cyrus  2006-present
# 4  1984-06-30                         [/wiki/Contemporary_R%26B]    /wiki/Fantasia_Barrino  2004-present

# %% [markdown]
# We merge the artist/song data frames into one large dataframe. Note that this has an effect of imputing to a song **all the genres** that the artist is active in. We know that this is not true, but it is the simplest assumption we can make, and is probably good for most artists. (To think: how might you check this?)

# %%
largedf=flatframe.merge(tempdf, on="url")
largedf.head()
# Out:
#    year  band_singer  ranking                                      song                                            songurl                url   born                      genres            ya
# 0  1992  Boyz II Men        1                           End of the Road                              /wiki/End_of_the_Road  /wiki/Boyz_II_Men  False  [/wiki/Contemporary_R%26B]  1985-present
# 1  1992  Boyz II Men       84                                   Uhh Ahh                                      /wiki/Uhh_Ahh  /wiki/Boyz_II_Men  False  [/wiki/Contemporary_R%26B]  1985-present
# 2  1992  Boyz II Men       37  It's So Hard to Say Goodbye to Yesterday   /wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday  /wiki/Boyz_II_Men  False  [/wiki/Contemporary_R%26B]  1985-present
# 3  1993  Boyz II Men       12                  In the Still of the Nite  /wiki/In_the_Still_of_the_Night_(1956_song)#Bo...  /wiki/Boyz_II_Men  False  [/wiki/Contemporary_R%26B]  1985-present
# 4  1994  Boyz II Men        3                     I'll Make Love to You                      /wiki/I%27ll_Make_Love_to_You  /wiki/Boyz_II_Men  False  [/wiki/Contemporary_R%26B]  1985-present

# %% [markdown]
# #### 2.2 Split out the genres

# %% [markdown]
# Update the dataframe by adding a column for each genre with true-false encoding for each row. This means, we want columns like "/wiki/Acid_house", "/wiki/Acid_jazz", where if an artist is in that genre, the dataframe cell has a python boolean, `True`. Otherwise, it has a `False`.
#
# Remember that an artist/band can be in multiple genres, and must have a "True" for each column corresponding to these genres, and false otherwise.
#
# This will widen the dataframe by the total number of genres that we have. The expanded part will look a bit like this:
#
# ![expansion](expandingframe.png)
#
# HINT: for example code see http://nbviewer.ipython.org/github/cs109/content/blob/master/lec_04_wrangling.ipynb, a notebook which lays out a very nice rubric for data analysis.

# %%
#your code here
#determine the unique genres
genres = set()
for genre in largedf.genres:
    genres.update(g for g in genre)
genres = sorted(genres)


for genre in genres:
    largedf[genre] = [genre in x for x in largedf.genres]      
largedf.head()
# genres = set()
# for genre in largedf.genres:
#     largedf[genre] = genres.update(g for g in largedf.genres["genres"])
# genres = sorted(genres)
# Out:
#    year  band_singer  ranking                                      song                                            songurl                url   born                      genres            ya /wiki/Acid_jazz /wiki/Acoustic_music /wiki/Adult_contemporary /wiki/Adult_contemporary_music /wiki/Afrobeat /wiki/Alternative_R%26B /wiki/Alternative_country /wiki/Alternative_dance /wiki/Alternative_dance#Indietronica /wiki/Alternative_hip_hop /wiki/Alternative_metal /wiki/Alternative_pop  \
# 0  1992  Boyz II Men        1                           End of the Road                              /wiki/End_of_the_Road  /wiki/Boyz_II_Men  False  [/wiki/Contemporary_R%26B]  1985-present           False                False                    False                          False          False                   False                     False                   False                                False                     False                   False                 False
# 1  1992  Boyz II Men       84                                   Uhh Ahh                                      /wiki/Uhh_Ahh  /wiki/Boyz_II_Men  False  [/wiki/Contemporary_R%26B]  1985-present           False                False                    False                          False          False                   False                     False                   False                                False                     False                   False                 False
# 2  1992  Boyz II Men       37  It's So Hard to Say Goodbye to Yesterday   /wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday  /wiki/Boyz_II_Men  False  [/wiki/Contemporary_R%26B]  1985-present           False                False                    False                          False          False                   False                     False                   False                                False                     False                   False                 False
# 3  1993  Boyz II Men       12                  In the Still of the Nite  /wiki/In_the_Still_of_the_Night_(1956_song)#Bo...  /wiki/Boyz_II_Men  False  [/wiki/Contemporary_R%26B]  1985-present           False                False                    False                          False          False                   False                     False                   False                                False                     False                   False                 False
# 4  1994  Boyz II Men        3                     I'll Make Love to You                      /wiki/I%27ll_Make_Love_to_You  /wiki/Boyz_II_Men  False  [/wiki/Contemporary_R%26B]  1985-present           False                False                    False                          False          False                   False                     False                   False                                False                     False                   False                 False
#
#   /wiki/Alternative_rock /wiki/Ambient_music /wiki/Anarcho-punk /wiki/Anti-folk /wiki/Art_pop /wiki/Art_rock /wiki/Baroque_pop /wiki/Bass_music /wiki/Battle_rap /wiki/Bhangra_(music) /wiki/Big_band /wiki/Big_room_house /wiki/Blue-eyed_soul /wiki/Bluegrass_music /wiki/Blues /wiki/Blues_rock /wiki/Breakbeat /wiki/British_hip_hop /wiki/Britpop /wiki/Bro-country /wiki/Broadway_theatre /wiki/Brown-eyed_soul /wiki/CEDM /wiki/Cajun_music /wiki/Celtic_music /wiki/Chicano_rock /wiki/Classical  \
# 0                  False               False              False           False         False          False             False            False            False                 False          False                False                False                 False       False            False           False                 False         False             False                  False                 False      False             False              False              False           False
# 1                  False               False              False           False         False          False             False            False            False                 False          False                False                False                 False       False            False           False                 False         False             False                  False                 False      False             False              False              False           False
# 2                  False               False              False           False         False          False             False            False            False                 False          False                False                False                 False       False            False           False                 False         False             False                  False                 False      False             False              False              False           False
# 3                  False               False              False           False         False          False             False            False            False                 False          False                False                False                 False       False            False           False                 False         False             False                  False                 False      False             False              False              False           False
# 4                  False               False              False           False         False          False             False            False            False                 False          False                False                False                 False       False            False           False                 False         False             False                  False                 False      False             False              False              False           False
#
#   /wiki/Cloud_rap /wiki/Comedy_music  ...   /wiki/Rave_music /wiki/Reggae /wiki/Reggae_fusion /wiki/Reggae_rock /wiki/Reggaeton /wiki/Rhythm_and_blues /wiki/Rock_and_roll /wiki/Rock_en_Espa%C3%B1ol /wiki/Rock_music /wiki/Roots_rock /wiki/Salsa_music /wiki/Shoegazing /wiki/Ska /wiki/Ska_punk /wiki/Skate_punk /wiki/Smooth_jazz /wiki/Soca_music /wiki/Soft_rock /wiki/Sophisti-pop /wiki/Soul_music /wiki/Southern_hip_hop /wiki/Southern_rock /wiki/Space_rock /wiki/Spoken_word /wiki/Synthpop  \
# 0           False              False  ...              False        False               False             False           False                  False               False                      False            False            False             False            False     False          False            False             False            False           False              False            False                  False               False            False             False          False
# 1           False              False  ...              False        False               False             False           False                  False               False                      False            False            False             False            False     False          False            False             False            False           False              False            False                  False               False            False             False          False
# 2           False              False  ...              False        False               False             False           False                  False               False                      False            False            False             False            False     False          False            False             False            False           False              False            False                  False               False            False             False          False
# 3           False              False  ...              False        False               False             False           False                  False               False                      False            False            False             False            False     False          False            False             False            False           False              False            False                  False               False            False             False          False
# 4           False              False  ...              False        False               False             False           False                  False               False                      False            False            False             False            False     False          False            False             False            False           False              False            False                  False               False            False             False          False
#
#   /wiki/Tech_house /wiki/Techno /wiki/Teen_pop /wiki/Thrash_metal /wiki/Traditional_pop_music /wiki/Trap_music /wiki/Trip_hop /wiki/UK_funky /wiki/UK_garage /wiki/Underground_hip_hop /wiki/Urban_adult_contemporary /wiki/Urban_contemporary /wiki/Urban_contemporary_gospel /wiki/West_Coast_Rap /wiki/West_Coast_hip_hop /wiki/West_coast_hip_hop /wiki/Witch_house_(music_genre) /wiki/World_music /wiki/Worldbeat Broadway     NA    Pop Pop, R&B, Adult Contemporary, Soul, Urban, Gospel Pop, hip hop  \
# 0            False        False          False              False                       False            False          False          False           False                     False                          False                    False                           False                False                    False                    False                           False             False           False    False  False  False                                             False        False
# 1            False        False          False              False                       False            False          False          False           False                     False                          False                    False                           False                False                    False                    False                           False             False           False    False  False  False                                             False        False
# 2            False        False          False              False                       False            False          False          False           False                     False                          False                    False                           False                False                    False                    False                           False             False           False    False  False  False                                             False        False
# 3            False        False          False              False                       False            False          False          False           False                     False                          False                    False                           False                False                    False                    False                           False             False           False    False  False  False                                             False        False
# 4            False        False          False              False                       False            False          False          False           False                     False                          False                    False                           False                False                    False                    False                           False             False           False    False  False  False                                             False        False
#
#     rock
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Q3. Exploratory Data Analysis (EDA)

# %% [markdown]
# At this point we have one dataframe `flatframe` for the songs, and one merged dataframe which has the songs with artist info in each row for each song, `largedf`.
#
# Our first visualization is an attempt to answer the following question:

# %% [markdown]
# ### What has been the trajectory of various genres in the popular zeitgeist?

# %% [markdown]
# We will use the trends in the Billboard top 100 as evidence. To that goal, let us see which are the 24 most popular genres.

# %% [markdown]
# To do this, we calculate the mean of the dataframe and eliminate the first two columns (`year` and `ranking`) to get means of all the genre columns. We sort it in ascending order, multiply by 100 to get percentages, and pick the top 24.

# %%
# Get the mean of all the *numerical* values, over the column axis (0).
# This works because True is numerically equal to 1 in Python (e.g. True + True == 2)
# so mean sums up the trues and divides by the total
#and it only does it for numerical columns
genrefrac = largedf.mean(axis=0)*100
# The first two numerical values are ranking and year, so start from the third.
genrefrac = genrefrac[2:]
# Sort the values in descending order (note that the sort method changed the list in place).
#This is because its a series sort. Pandas Dataframe sorts, the type we used earlier, do not
#do the sort in place.
genrefrac.sort(ascending=False)
# Get the first 24 items.
genrefrac[:24]
# Out:
# /wiki/Hip_hop_music             38.301501
# /wiki/Contemporary_R%26B        34.652115
# /wiki/Pop_music                 29.843111
# /wiki/Soul_music                 9.924966
# /wiki/Pop_rock                   8.833561
# /wiki/Alternative_rock           7.946794
# /wiki/Country_music              6.139154
# /wiki/Rock_music                 5.388813
# /wiki/Dance-pop                  4.774898
# /wiki/Dance_music                4.672578
# /wiki/Post-grunge                2.626194
# /wiki/Neo_soul                   2.557981
# /wiki/Reggae                     2.455662
# /wiki/Hard_rock                  2.421555
# /wiki/Electronic_dance_music     2.285130
# /wiki/Electropop                 2.182810
# /wiki/Hip_hop_soul               2.114598
# /wiki/Funk                       2.114598
# /wiki/Soft_rock                  1.807640
# /wiki/Synthpop                   1.705321
# /wiki/Gospel_music               1.603001
# /wiki/Folk_music                 1.568895
# /wiki/House_music                1.568895
# /wiki/Pop_punk                   1.534789
# dtype: float64

# %% [markdown]
# ####3.1 Plot a horizontal bar chart of the top 30 genres

# %% [markdown]
# You will have to change the index of the `genrefrac` series to strip `/wiki` from the genre names, and convert underscores to spaces. **Hint**: Use the pandas `plot`, `reset_index` and `set_index` methods. Label the y-axis "Genres".

# %%
#your code here

#cleaning & making a new list
genrelist = []
for genre in genrefrac.index[:30]:
    #get rid of /wiki/ and _
    genre = genre.replace('/wiki/','')
    genre = genre.replace('_',' ')
    genrelist.append(genre)
print type(genrefrac)

#plotting
plot_genre = genrefrac[:30].plot(y = 'Genres', kind = 'barh')
plot_genre.set_yticklabels(genrelist)
plot_genre.set_ylabel('Genres')
plot_genre.set_xlabel('Percent')
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Lets take the top 24 genres from `genrefrac`. For each genre, we create a subframe of the ranking and year from those rows for which that genre is "True". We group the resulting dataframe by year. We obtain a dictionary `genreinfo` keyed by genre, whose value is a tuple of 3 Pandas series: the mean rankings per year for that genre, the standard deviation on those rankings, and the series groupby object for the rankings per year.

# %%
genreinfo={}
topgenres=genrefrac.index[:24]
for genre in topgenres:
    genreframe=largedf[largedf[genre]==True][['ranking','year']]
    ggby = genreframe.groupby('year')
    genreinfo[genre]={'meanseries': ggby['ranking'].mean(), 'stdseries': ggby['ranking'].std(), 'rankingseries': ggby['ranking']}
genreinfo['/wiki/Funk']
# Out:
# {'meanseries': year
#  1992    36.142857
#  1993    53.500000
#  1994    49.400000
#  1995    22.000000
#  1996    45.000000
#  1999    11.000000
#  2000    76.000000
#  2001    83.000000
#  2002    63.000000
#  2003    47.200000
#  2004    76.333333
#  2005    23.000000
#  2006    25.000000
#  2007    55.500000
#  2008    50.000000
#  2009    97.000000
#  2010    41.500000
#  2011    92.000000
#  2012    44.000000
#  2013    45.800000
#  2014    50.000000
#  Name: ranking, dtype: float64,
#  'rankingseries': <pandas.core.groupby.SeriesGroupBy object at 0x110dcc2d0>,
#  'stdseries': year
#  1992    30.163049
#  1993     6.244998
#  1994    34.399128
#  1995    22.102036
#  1996          NaN
#  1999    12.727922
#  2000          NaN
#  2001          NaN
#  2002     1.414214
#  2003    16.468151
#  2004     9.237604
#  2005     0.000000
#  2006    14.142136
#  2007    46.679760
#  2008          NaN
#  2009          NaN
#  2010    53.033009
#  2011          NaN
#  2012    48.135226
#  2013    37.525991
#  2014    33.083228
#  Name: ranking, dtype: float64}

# %% [markdown]
# Notice that there are NaN's in the standard deviations. Pandas calculates standard deviations for samples rather than populations, and if there is only 1 item, then the standard deviation calculation involves a division by 0.

# %% [markdown]
# #### 3.2 Make a small multiples plot of the 24 most popular genres

# %% [markdown]
# Make a 8 row, 3 column small multiples plot with elements like:
#
# ![Small Multiple](smmult.png)
#
# You will use `genreinfo`, which we just computed, to make a plot of how the "ranking of a genre" has changed with time. The mean rank achieved by songs in a genre forms the backbone of this plot, with the standard deviation shown, and rankings of all the songs in the genre that year shown as well, at a very low transparency. (Since a song belongs to many genres through the artist, this means that a song may be represented in multiple plots. Again, while not strictly true, this is a simplifying assumption we are making.)
#
# Some instructions for the plot:
#
# 1. The blue scatters are all the songs "in" that genre: keep them at a low alpha so one can visually see the density.
# 2. The dark red points are the means. You can choose to join them if you like.
# 3. The light red band uses matplotlib's `fill_between` to fill the area between `mean-std` and `mean+std`.
# 4. If the standard deviation is NaN, fill up the entire y dimension with it to give a notion of large impreciseness in the measure.
#
# HINT: Once again, http://nbviewer.ipython.org/github/cs109/content/blob/master/lec_04_wrangling.ipynb may help in creating such a plot.
#
# If you have a better viz for this, by all means go for it!

# %%
#your code here

#your code here
#create a 8x3 grid of plots.
import operator
fig, axes = plt.subplots(nrows=3, ncols=8, figsize=(30, 10), tight_layout=True)

bins = np.arange(1992, 2014, 1)
for ax,genre in zip(axes.ravel(),topgenres):
    #plot means
    ax.scatter(genreinfo[genre]['meanseries'].index,genreinfo[genre]['meanseries'].values,color='r',alpha=.2)
    #plot std.dev's
    ax.scatter(genreinfo[genre]['stdseries'].index,genreinfo[genre]['stdseries'].values,color='g',alpha=.2)
    #plot rankings
    for year,group in genreinfo[genre]['rankingseries']:
        for rank in group:
            ax.scatter(year,rank,color='b',alpha=.1) 
    #calculate std.dev & fill
    std = np.mean(genreinfo[genre]['stdseries'].values)
    if np.isnan(std):
        ax.fill_between(genreinfo[genre]['meanseries'].index,0,100,facecolor='yellow',alpha=.1)
    else:
        ax.fill_between(genreinfo[genre]['meanseries'].index,map(operator.sub,genreinfo[genre]['meanseries'].values,genreinfo[genre]['stdseries'].values), map(operator.add,genreinfo[genre]['meanseries'].values,genreinfo[genre]['stdseries'].values), facecolor='yellow',alpha=.2)
    #structure axes and labels
    ax.set_ylim([0,100])
    ax.set_xlim([1992,2015])
    ax.set_title(genre.replace("/wiki/","").replace("%26","&").replace("_"," "))
    ax.set_xlabel('Year')

# %% [markdown]
# **3.2(contd) What trends do you see?**
#
# Write a paragraph or two, touching on which genres are the most popular, and how this popularity has changed over time.

# %% [markdown]
# *your answer here*
# Hip hop, contemporary R&B, and pop music clearly established themselves as the 3 most popular genres of the time.  They were also very consistent, as not only did their mean ranks tend to stay the same (see the red dots), but so did their standard deviations as well (as illustrated by the yellow filling).  Other genres had much less songs with high rankings, and thus were much more inconsistent in their performance (as illustrated by the huge fills of yellow on their graphs).

# %% [markdown]
# ### Who are the highest quality singers?

# %% [markdown]
# Here we show the highest quality singers and plot them on a bar chart.
#
# What do we mean by highest quality? This is of-course open to interpretation, but lets define "highest quality" here as the number of times a singer appears in the top 100 over this time period. If they appear twice in a year(for different songs), this is counted as two appearances, not one. We cut our chart of at those singers who have appeared more than 15 times.

# %%
prolific=flatframe.url.value_counts()
prolific[prolific > 15].plot(kind="barh");

# %% [markdown]
# #### 3.3 What if we used a different metric?

# %% [markdown]
# What we would like to capture is this: a singer ought to be scored higher if he or she appears higher in the rankings. So we'd say that a singer who appeared once at a higher and once at a lower ranking is a "higher quality" singer than one who appeared twice at a lower ranking.
#
# To do this, group all of a singers songs together and assign each song a score `101 - ranking`. Order the singers by their total score and make a bar chart for the top 20.

# %%
#your code here
#make a score column
flatframe['newcol'] = flatframe.ranking.apply(lambda x: 101-x)
data = flatframe.groupby('band_singer')
singerscores = data.newcol.sum()
#sort in decreasing order
singerscores.sort(0,False)
#plot top 20
singerscores[:20].plot(kind='barh')

# %% [markdown]
# **3.3(contd)Do you notice any major differences when you change the metric?**
#
# How have the singers at the top shifted places? Why do you think this is so?

# %% [markdown]
# *your answer here*
# Rihanna has maintained her lead, proving that she prolifically produces music that is well-received by the audience (according to Billboard, at least).  The first metric favors artists who produce music often (no matter what rank they achieve on the Billboard top 100), while the second metric favors artists who produce high-scoring music often, thus providing a more holistic approach.

# %% [markdown]
# #### The age at which singers achieve their top ranking.

# %% [markdown]
# As an example to warm you up for the next question, we plot a histogram of the age at which singers achieve their top ranking

# %%
dfb=largedf[largedf.born!=False][['year','born','ranking','url']]
#get the birth year
dfb['byear']=dfb.born.apply(lambda x: int(x[:4]))
byurl=dfb.groupby('url')
frames=[]
for k, v in byurl:
    minr=v.ranking.min()
    frames.append(v[v.ranking==minr])
topscoresdf=pd.concat(frames)
(topscoresdf.year-topscoresdf.byear).hist(bins=np.arange(10,70,5), normed=True);

# %% [markdown]
# The *age of first fame* has an interesting shape, unimodal with a mode in the late 20s with a long tail to the right. This makes sense because there really is a lower age limit to artists but not so much an upper one. So you expect this type of behavior.

# %% [markdown]
# #### 3.4 At what year since inception do bands reach their top rankings?

# %% [markdown]
# Make a similar calculation to plot a histogram of the years since inception at which bands reach their top ranking

# %%
#your code here
dfb=largedf[largedf.ya!=False][largedf.born == False][['year','born','ranking','url','ya']]
#get start year
dfb['aya']=dfb.ya.apply(lambda x: int(x[:4]))
byurl=dfb.groupby('url')
frames=[]
for k, v in byurl:
    minr=v.ranking.min()
    frames.append(v[v.ranking==minr])
topscoresdf=pd.concat(frames)
(topscoresdf.year-topscoresdf.aya).hist(bins=np.arange(0,70,5), normed=True);

# %% [markdown]
# ## Q4: Billboard Magazine: year end results from weekly results

# %% [markdown]
# The aim of this problem is to find features in the weekly Billboard top 100 that can predict the end year results. In the interests of time, we'll only do 2014: a complete study would do all the years.
# Let us first fetch the end-of-year results.

# %% [markdown]
# ### Get the end year results, and results from all saturdays of the year.

# %%
end_year=requests.get("http://www.billboard.com/charts/year-end/2014/hot-100-songs").text

# %% [markdown]
# Billboard releases its daily ratings on saturdays.

# %% [markdown]
# We first write a function `allsats(year, fs)` to get all the saturdays in a given year, and given the day part of the date of the first saturday of the year in january. We use the `date` and `timedelta` modules.

# %%
from datetime import date, timedelta

def allsats(year, fs):
    days=[]
    d = date(year, 1, fs)       
    while d.year == year:
        days.append(d.strftime("%Y-%m-%d"))
        d += timedelta(days = 7)
    return days

# %% [markdown]
# The first Saturday in 2014 is Jan 4th:

# %%
sats=allsats(2014, 4)
sats
# Out:
# ['2014-01-04',
#  '2014-01-11',
#  '2014-01-18',
#  '2014-01-25',
#  '2014-02-01',
#  '2014-02-08',
#  '2014-02-15',
#  '2014-02-22',
#  '2014-03-01',
#  '2014-03-08',
#  '2014-03-15',
#  '2014-03-22',
#  '2014-03-29',
#  '2014-04-05',
#  '2014-04-12',
#  '2014-04-19',
#  '2014-04-26',
#  '2014-05-03',
#  '2014-05-10',
#  '2014-05-17',
#  '2014-05-24',
#  '2014-05-31',
#  '2014-06-07',
#  '2014-06-14',
#  '2014-06-21',
#  '2014-06-28',
#  '2014-07-05',
#  '2014-07-12',
#  '2014-07-19',
#  '2014-07-26',
#  '2014-08-02',
#  '2014-08-09',
#  '2014-08-16',
#  '2014-08-23',
#  '2014-08-30',
#  '2014-09-06',
#  '2014-09-13',
#  '2014-09-20',
#  '2014-09-27',
#  '2014-10-04',
#  '2014-10-11',
#  '2014-10-18',
#  '2014-10-25',
#  '2014-11-01',
#  '2014-11-08',
#  '2014-11-15',
#  '2014-11-22',
#  '2014-11-29',
#  '2014-12-06',
#  '2014-12-13',
#  '2014-12-20',
#  '2014-12-27']

# %% [markdown]
# #### Get the data

# %% [markdown]
# Let us use `requests` to get the billboard pages for all these days. The format for the data is a dictionary `satdict` with keys the saturday date strings we see above, and one additional key, `end_year`. The values corresponding to the keys are the html text downloaded from billboard. The value corresponding to the `end_year` key comes from the `end_year` variable.
#
# Billboard makes the lists for every saturday available at:
# `http://www.billboard.com/charts/hot-100/saturday`, for example, http://www.billboard.com/charts/hot-100/2014-12-27 .

# %%
satdict={}
satdict['end_year']=end_year
for sat in sats:
    satdict[sat]=requests.get("http://www.billboard.com/charts/hot-100/"+sat).text
    time.sleep(1)

# %% [markdown]
# We save the output in a file, `satdict.json`.

# %%
with open("tempdata/satdict.json","w") as fd:
    json.dump( satdict, fd)
del satdict
with open("tempdata/satdict.json") as fd:
    satdict=json.load(fd)

# %% [markdown]
# #### 4.1 Parse the HTML and save the song information

# %% [markdown]
# Write a function `get_weekly(weekstring, indict)` which takes the string corresponding to a saturday, `weekstring` and a dictionary `indict` with *keys* as the saturdays and *value* as the text of the billboard page for that day. Parse the text, returning a list of tuples `(ranking, songdict)` with a `songdict` dictionary. Each tuple corresponds to a song in that week's top-100, with `ranking` the ranking of that song.
#
# One of these pages looks like this in the developer tools:
#
# ![billboard](billboard.png)
#
# Make the dictionary `songdict` look like this:
#
# `songdict=dict(ranking=ranking, title=title)`
#
# where the title is the title of the song. The `ranking` is the same `ranking` that is the first element of the tuple.

# %%
"""
Function
--------
get_weekly

Inputs
------
weekstring: the saturday in question
indict: a dictionary with keys being saturdays, and values being the billboard html associated
with those saturdays
   
Returns
-------
A list of tuples. Each tuple has two elements. The first element is the ranking. The
second is a dictionary songdict with keys
    ranking: ranking of song. same as first element of the tuple
    title: title of song


Notes
-----
See description above.
"""
#your code here
def get_weekly(weekstring,indict):
    page_text = indict[weekstring]
    page_text = BeautifulSoup(page_text, 'html.parser')
    rows = page_text.find("div", attrs={"class": "chart-data"}).find_all("div",attrs={"class":"container"})
    song_tuples_list = []
    for row in rows:
        songs = row.find_all("article", attrs={"class":"chart-row"})
        for song in songs:
            songdict = {}
            ranking_songtuple = ()
            each_song = song.find("div", attrs={"class":"row-title"}).find("h2").get_text()
            each_song = str(each_song.replace("\t","").replace("\n",""))
            ranking = int(song.find("div",attrs={"class":"row-rank"}).find("span").get_text())
            #print each_song
            songdict['title'] = each_song
            songdict['ranking'] = ranking
            #print songdict
            song_tuples_list.append((ranking,songdict))
    #for song_tuple in song_tuples_list:
    #    print song_tuple
    return song_tuples_list

#get_weekly('2014-12-27',satdict)

# %% [markdown]
# Let's process the weekly and year-end information using the function you just defined. We create a `weekinfo` list with the above function run for each week. We also store in the variable `yearend` the results of running the function for the end of year rankings. We `zip` the `weekinfo` together with the saturdays to create a list of tuples `weektuples`.

# %%
weekinfo=[]
for k in sats:
    weekinfo.append(get_weekly(k, satdict))
yearend=get_weekly('end_year', satdict)
weektuples=zip(sats, weekinfo)

# %% [markdown]
# ---
#
# Here we write a function `get_for_title(weektups)` that takes the tuples created above and returns a dictionary `titles` whose *key* is the title of the song, and whose *value* is a list of tuples, the members of which are (`weekindex`, `ranking`). The `weekindex` starts at 1 for the first week of the year, and `ranking` is the ranking achieved that week.

# %%
def get_for_title(weektups):
    titles={}
    weekindex=1
    for weekdate, weeksrankings in weektups:
        for rankingtuple in weeksrankings:#iterate over the week's top-100
            ranking = rankingtuple[0]
            weekdict=rankingtuple[1]
            if not titles.has_key(weekdict['title']):
                titles[weekdict['title']]=[]
            titles[weekdict['title']].append((weekindex, ranking))
        weekindex=weekindex+1
    return titles

# %%
titles = get_for_title(weektuples)

# %% [markdown]
# Now let's create a dictionary keyed by the lower-cased title where we store the rank means (`rankmean`), rank standard deviations (`rankstd`) and rank count, the number of times(weeks) it appeared in the rankings in 2014, (`ranklen`), for a song.

# %%
tdict={}
for title in titles.keys():
    wtlist=titles[title]
    weeks=[e[0] for e in wtlist]
    ranks=[e[1] for e in wtlist]
    rankmean=np.mean(ranks)
    rankstd=np.std(ranks, ddof=1)#numpy standard deviation is population based, make it sample based
    ranklen=len(ranks)
    tdict[title.lower()]={'ranks':(rankmean, rankstd, ranklen)}

# %% [markdown]
# ### Get winning songs, and see how they do in all these weeks

# %% [markdown]
# Now we create a list of winners whose elements are `dict(title, winner=1, ranking=year-end-ranking, rankmean=mean over weeks, rankstd=stddev over weeks, weekson=ranklen)`. To make this, we go to the songs that are in the top 100 at years-end and pick up their information from `tdict` above.

# %%
winners=[]
for yt in yearend:
    r,d =yt
    title=d['title'].lower()
    rvals=tdict[title]['ranks']
    winners.append(dict(title=title, winner=1, ranking=d['ranking'], rankmean=rvals[0], rankstd=rvals[1], weekson=rvals[2]))

# %% [markdown]
# And we use this list of dictionaries to create a dataframe `winners2014` with al the information gathered.

# %%
winners2014=pd.DataFrame(winners)
winners2014.head()
# Out:
#    ranking   rankmean    rankstd           title  weekson  winner
# 0        1  18.063830  19.687123           happy       47       1
# 1        2  14.272727  14.744906      dark horse       44       1
# 2        3  17.959184  17.744670       all of me       49       1
# 3        4  24.256410  26.708680           fancy       39       1
# 4        5  20.690476  15.123053  counting stars       42       1

# %% [markdown]
# #### 4.2 Plot the mean rank(y axis) against the final, year-end rank(x-axis)

# %% [markdown]
# Show a 45 degree line for comparison. Use `plt.errorbar` to show the standard deviation along with the mean rank.

# %% [markdown]
# **4.2(contd)Comment on the trend in this plot. **
#
# In a paragraph, tell us how the general trend compares to the 45 degree line? What does this say about the predictive ability of the average rank for the final rank?

# %%
# your code here
#print winners2014
#plot = plt.scatter(winners2014['rankmean'],winners2014['ranking'])
plt.errorbar(winners2014['ranking'],winners2014['rankmean'],winners2014['rankstd'],ecolor='pink',color='green')
plt.xlabel('Year-End Rank')
plt.ylabel('Mean Rank')
plt.plot(range(100),range(100),'indigo')

# %% [markdown]
# *your answer here*
# The indigo 45-degree line is what would happen if Billboard calculated the Year-End Rank purely on the Mean Rank of that song.  The plot illustrates that Billboard does NOT in fact calculate their year-end rankings based off the mean (if at all), but could also factor in other variables, such as how long a certain song maintained the rank, or even how long the song was NOT in the ranks.  For instance, songs that tended to have a high mean ranking (40 or higher) sometimes ended up with a lower (as in 50 or higher) year-end rankings, proving that other factors were being taken into account (such as duration of a song's position on Billboard's 100).

# %% [markdown]
# ###Add losers in and see what features may be used to distinguish winners from losers

# %% [markdown]
# Let's create a list `losers` of dictionaries, one for each song from the weekly lists that did not make it to the year end list. The dictionaries are identical to the dictionaries in the `winners` list, but we code the `ranking` as -1 for losers and set `winner` to 0. Thus

# %%
winlist=[e['title'] for e in winners]
losers=[]
for title in tdict:
    if not title in winlist:
        rvals=tdict[title]['ranks']
        losers.append(dict(title=title, winner=0, ranking=-1, rankmean=rvals[0], rankstd=rvals[1], weekson=rvals[2]))

# %% [markdown]
# We create a `losers2014` dataframe...

# %%
losers2014=pd.DataFrame(losers)
losers2014.head()
# Out:
#    ranking   rankmean    rankstd                          title  weekson  winner
# 0       -1  17.000000   7.949843  the heart wants what it wants        6       0
# 1       -1  77.333333   5.841031               do i wanna know?       18       0
# 2       -1  86.000000   9.626353              shut up and dance        4       0
# 3       -1  52.350000  14.477842       give me back my hometown       20       0
# 4       -1  72.350000  17.631536    hope you get lonely tonight       20       0

# %% [markdown]
# ...and concatenate the losers and winners into one dataframe.

# %%
all2014=pd.concat([winners2014, losers2014])
all2014.head()
# Out:
#    ranking   rankmean    rankstd           title  weekson  winner
# 0        1  18.063830  19.687123           happy       47       1
# 1        2  14.272727  14.744906      dark horse       44       1
# 2        3  17.959184  17.744670       all of me       49       1
# 3        4  24.256410  26.708680           fancy       39       1
# 4        5  20.690476  15.123053  counting stars       42       1

# %% [markdown]
# ####4.3 Make a scatterplot matrix of these features, color coded by winners/losers

# %% [markdown]
# Use `sns.pairplot`. Use all the numerical features(4), with the exception of `winner`, which you will use to give a different color to winners and losers. This will be a 4x4 matrix, with different colored dots for winners and losers off diagonal, and a 2 histograms on diagonal. The histogram shows the distribution of the one feature on the diagonal for both the winners and losers.

# %%
#your code here
#Søürcé: http://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.pairplot.html
sns.pairplot(all2014,hue='winner',vars= ["ranking", "rankmean", "weekson","rankstd"], dropna=True)

# %% [markdown]
# **4.3 (contd) Which combination of "features" is most likely to separate winners from losers? **
#
# It is this kind of observation in EDA that forms the basis for staring on predictive modelling! In a paragraph, identify one or two combinations of features that you think will best separate winners from losers. Why?

# %% [markdown]
# *your answer here*
# We shouldn't use the ranks because they only contain given information, so they don't tell us anything new.  One good combination we could use is the weeks on vs. rank mean.  This is useful because it shows (as expected), that songs that were on the charts longer tended to have a better (as in lower number) mean rank.

# %% [markdown]
#  **Until next time.**
